# %% [markdown]
# # technicals
#
# > This module implements various methods for adding several technical indicators and metrics to the raw bhavcopy data.

# %%
#| default_exp technicals

# %%
#| hide
import nbdev
from nbdev.showdoc import *

# %%
#| export
import pandas as pd
import os
import numpy as np
from pathlib import Path
import pandas_ta as pdta
import nbdev

# %%
#| export
base_path = nbdev.config.get_config().lib_path

# %%
#| export
raw_data_dir = base_path / "../Data/Bhavcopy/Raw"
processed_data_dir = base_path / "../Data/Bhavcopy/Processed"

# %%
#| export
bhavcopy_dtypes = {
    "SYMBOL": 'string',
    "SERIES": 'string',
    "OPEN": 'float64',
    "HIGH": 'float64',
    "LOW": 'float64',
    "CLOSE": 'float64',
    # "LAST": 'float64',
    # "PREVCLOSE": 'float64',
    "TOTTRDQTY": 'int64',
    "TOTTRDVAL": 'float64',
    "TIMESTAMP": 'string',
    "TOTALTRADES": 'int64',
    # "ISIN": 'string',
    # "Unnamed: 13": 'string',
}

bhavcopy_usecols = [
    "SYMBOL",
    "SERIES",
    "OPEN",
    "HIGH",
    "LOW",
    "CLOSE",
    # "LAST",
    # "PREVCLOSE",
    "TOTTRDQTY",
    "TOTTRDVAL",
    "TIMESTAMP",
    "TOTALTRADES",
    # "ISIN",
    # "Unnamed: 13",
]

# %%
#| export
# Read single day bhavcopy file
def load_bhavcopy(file_path, stocks_list=None):
    df = pd.read_csv(
        file_path,
        dtype=bhavcopy_dtypes,
        usecols=bhavcopy_usecols,
        parse_dates=["TIMESTAMP"],
        dayfirst=False,
    )
    return df[df.SYMBOL.isin(stocks_list)] if stocks_list else df

# %%
#| export
# Preprocess bhavcopy data
def preprocess(df):
    return (df
            .pipe(lambda x: x[x["SERIES"] == "EQ"])
            .assign(
                DATE=pd.to_datetime(df.TIMESTAMP, format="%d-%b-%Y").dt.date,
                DAY_OF_WEEK = pd.to_datetime(df.TIMESTAMP, format="%d-%b-%Y").dt.day_name(),
                WEEK_NUM = pd.to_datetime(df.TIMESTAMP, format="%d-%b-%Y").dt.isocalendar().week,  
            )
            .drop(columns=["TIMESTAMP",])  
            .sort_values(["SYMBOL", "DATE"])
            .reset_index(drop=True)
            # .set_index("DATE")
        )

# %%
#| export
# Generate simple moving average data
def get_sma(df_symbol, period=20, metric="CLOSE"):
    if metric.upper() in ["CLOSE", "OPEN", "HIGH", "LOW"]:
        return pdta.sma(df_symbol[metric], length=period).rename(f"SMA_{period}_{metric.upper()[0]}")
    else:
        raise ValueError("Invalid metric")

# %%
#| export
# Generate donchian channel data
def get_donchian(df_symbol, upper=22, lower=66):
    return (pdta.donchian(df_symbol.HIGH, df_symbol.LOW, lower_length=66, upper_length=22)
                .rename(
                    columns={
                        f"DCL_{lower}_{upper}": f"DONCHIAN_L{lower}", 
                        f"DCU_{lower}_{upper}": f"DONCHIAN_U{upper}"})
                .drop(columns=[f"DCM_{lower}_{upper}"])
                )

# %%
#| export
# Generate supertrend data
def get_supertrend(df_symbol, period=10, multiplier=3):
    return (pdta.supertrend(
        df_symbol.HIGH, df_symbol.LOW, df_symbol.CLOSE,
        length=period, multiplier=multiplier
        )
        .drop(columns=[
            f"SUPERT_{period}_{multiplier:.1f}",
            f"SUPERTl_{period}_{multiplier:.1f}",
            f"SUPERTs_{period}_{multiplier:.1f}",
            ])
        .rename(columns={
            f"SUPERTd_{period}_{multiplier:.1f}": f"SUPTR_{period}_{multiplier}"
            })
        )

# %%
#| export
# Generate candlestick data
def get_candle_stats(df_symbol):
    df_tmp = pd.DataFrame()
    return (df_tmp
            .assign(
        CDL_COLOR=df_symbol.apply(lambda x: np.where(x.CLOSE > x.OPEN, "green", "red"), axis=1),
        CDL_SIZE = abs(df_symbol.CLOSE - df_symbol.OPEN),
        TOPWICK_SIZE = df_symbol.HIGH - df_symbol[["OPEN", "CLOSE"]].max(axis=1),
        BOTWICK_SIZE = df_symbol[["OPEN", "CLOSE"]].min(axis=1) - df_symbol.LOW,
    )
    )

# %%
#| export
# Generate misc technical indicators
def get_misc_stats(df_symbol):
    return (df_symbol
            .assign(
                # CDL_SIZE_AVG_22 = df_symbol.CDL_SIZE.rolling(22).mean(),
                # CDL_SIZE_AVG_12 = df_symbol.CDL_SIZE.rolling(12).mean(),
                # CDL_SIZE_MAX_22 = df_symbol.CDL_SIZE.rolling(22).max(),
                # CDL_SIZE_MAX_12 = df_symbol.CDL_SIZE.rolling(12).max(),
                DIFF_20_44 = (df_symbol.SMA_20_C - df_symbol.SMA_44_C).abs(),
                DIFF_20_200 = (df_symbol.SMA_20_C - df_symbol.SMA_200_C).abs(),
                DIFF_20_CLOSE = (df_symbol.SMA_20_C - df_symbol.CLOSE).abs(),
                DIFF_44_CLOSE = (df_symbol.SMA_44_C - df_symbol.CLOSE).abs(),
                DIFF_200_CLOSE = (df_symbol.SMA_200_C - df_symbol.CLOSE).abs(),
                # AVGTRDQTY=df_symbol.TOTTRDQTY / df_symbol.TOTALTRADES,
                # AVGTRDVAL=df_symbol.TOTTRDVAL / df_symbol.TOTALTRADES,
            )
    )

# %%
#| export
# Generate all technicals for a symbol data
def add_all_technicals(df_symbol):
    df_symbol = df_symbol.reset_index().sort_values(by="DATE", inplace=False)
    return (pd.concat(
        [
            df_symbol,
            # get_sma(df_symbol, 8),
            get_sma(df_symbol, 20, "CLOSE"),
            get_sma(df_symbol, 20, "HIGH"),
            get_sma(df_symbol, 44),
            get_sma(df_symbol, 200),
            # get_donchian(df_symbol, upper=22, lower=66),
            # get_supertrend(df_symbol, period=12, multiplier=3),
            # get_supertrend(df_symbol, period=11, multiplier=2),
            # get_supertrend(df_symbol, period=10, multiplier=1),
            get_candle_stats(df_symbol),
        ],
        axis=1
        )
            .pipe(get_misc_stats)
            # .assign(
            #     DATE = df_symbol.DATE.dt.strftime("%Y-%M-%d"),
            # )
              )

# %%
#| export

# Get list of all csv files in raw_data_dir
csv_files = [f for f in raw_data_dir.iterdir() if f.suffix == '.csv']

# Read all csv files into a single dataframe
df = pd.concat(
        [load_bhavcopy(os.path.join(raw_data_dir, f), None) for f in csv_files],
        ignore_index=True
        )

df = preprocess(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [9], line 8
#       4 csv_files = [f for f in raw_data_dir.iterdir() if f.suffix == '.csv']
#       6 # Read all csv files into a single dataframe
#       7 df = pd.concat(
# ----> 8         [load_bhavcopy(os.path.join(raw_data_dir, f), None) for f in csv_files],
#       9         ignore_index=True
#      10         )
#      12 df = preprocess(df)
#
# Cell In [9], line 8, in <listcomp>(.0)
#       4 csv_files = [f for f in raw_data_dir.iterdir() if f.suffix == '.csv']
#       6 # Read all csv files into a single dataframe
#       7 df = pd.concat(
# ----> 8         [load_bhavcopy(os.path.join(raw_data_dir, f), None) for f in csv_files],
#       9         ignore_index=True
#      10         )
#      12 df = preprocess(df)
#
# NameError: name 'load_bhavcopy' is not defined

# %%
#| export

for symbol, df_symbol in df.groupby("SYMBOL"):
    if len(df_symbol) > 200:
        df_symbol = add_all_technicals(df_symbol)
        # print(df_symbol)
        # print(df_symbol.columns)
        
        file_path = os.path.join(processed_data_dir, f"{symbol}.csv")
        df_symbol.to_csv(file_path, index=True)
        print(f"Saved {file_path}")
# Out:
# Saved ../Data/Bhavcopy/Processed\20MICRONS.csv
# Saved ../Data/Bhavcopy/Processed\21STCENMGM.csv
# Saved ../Data/Bhavcopy/Processed\3IINFOLTD.csv
# Saved ../Data/Bhavcopy/Processed\3IINFOTECH.csv
# Saved ../Data/Bhavcopy/Processed\3MINDIA.csv
# Saved ../Data/Bhavcopy/Processed\3PLAND.csv
# Saved ../Data/Bhavcopy/Processed\5PAISA.csv
# Saved ../Data/Bhavcopy/Processed\63MOONS.csv
# Saved ../Data/Bhavcopy/Processed\8KMILES.csv
# Saved ../Data/Bhavcopy/Processed\A2ZINFRA.csv
# Saved ../Data/Bhavcopy/Processed\AAKASH.csv
# Saved ../Data/Bhavcopy/Processed\AAREYDRUGS.csv
# Saved ../Data/Bhavcopy/Processed\AARON.csv
# Saved ../Data/Bhavcopy/Processed\AARTIDRUGS.csv
# Saved ../Data/Bhavcopy/Processed\AARTIIND.csv
# Saved ../Data/Bhavcopy/Processed\AARTISURF.csv
# Saved ../Data/Bhavcopy/Processed\AARVEEDEN.csv
# Saved ../Data/Bhavcopy/Processed\AARVI.csv
# Saved ../Data/Bhavcopy/Processed\AAVAS.csv
# Saved ../Data/Bhavcopy/Processed\ABAN.csv
# Saved ../Data/Bhavcopy/Processed\ABB.csv
# Saved ../Data/Bhavcopy/Processed\ABBOTINDIA.csv
# Saved ../Data/Bhavcopy/Processed\ABCAPITAL.csv
# Saved ../Data/Bhavcopy/Processed\ABFRL.csv
# Saved ../Data/Bhavcopy/Processed\ABGSHIP.csv
# Saved ../Data/Bhavcopy/Processed\ABIRLANUVO.csv
# Saved ../Data/Bhavcopy/Processed\ABSLAMC.csv
# Saved ../Data/Bhavcopy/Processed\ABSLBANETF.csv
# Saved ../Data/Bhavcopy/Processed\ABSLNN50ET.csv
# Saved ../Data/Bhavcopy/Processed\ACC.csv
# Saved ../Data/Bhavcopy/Processed\ACCELYA.csv
# Saved ../Data/Bhavcopy/Processed\ACCURACY.csv
# Saved ../Data/Bhavcopy/Processed\ACE.csv
# Saved ../Data/Bhavcopy/Processed\ACRYSIL.csv
# Saved ../Data/Bhavcopy/Processed\ADANIENT.csv
# Saved ../Data/Bhavcopy/Processed\ADANIGAS.csv
# Saved ../Data/Bhavcopy/Processed\ADANIGREEN.csv
# Saved ../Data/Bhavcopy/Processed\ADANIPORTS.csv
# Saved ../Data/Bhavcopy/Processed\ADANIPOWER.csv
# Saved ../Data/Bhavcopy/Processed\ADANITRANS.csv
# Saved ../Data/Bhavcopy/Processed\ADFFOODS.csv
# Saved ../Data/Bhavcopy/Processed\ADHUNIK.csv
# Saved ../Data/Bhavcopy/Processed\ADHUNIKIND.csv
# Saved ../Data/Bhavcopy/Processed\ADI.csv
# Saved ../Data/Bhavcopy/Processed\ADLABS.csv
# Saved ../Data/Bhavcopy/Processed\ADORWELD.csv
# Saved ../Data/Bhavcopy/Processed\ADROITINFO.csv
# Saved ../Data/Bhavcopy/Processed\ADSL.csv
# Saved ../Data/Bhavcopy/Processed\ADVANIHOTR.csv
# Saved ../Data/Bhavcopy/Processed\ADVENZYMES.csv
# Saved ../Data/Bhavcopy/Processed\AEGISCHEM.csv
# Saved ../Data/Bhavcopy/Processed\AFFLE.csv
# Saved ../Data/Bhavcopy/Processed\AFL.csv
# Saved ../Data/Bhavcopy/Processed\AGARIND.csv
# Saved ../Data/Bhavcopy/Processed\AGCNET.csv
# Saved ../Data/Bhavcopy/Processed\AGLSL.csv
# Saved ../Data/Bhavcopy/Processed\AGRITECH.csv
# Saved ../Data/Bhavcopy/Processed\AGROPHOS.csv
# Saved ../Data/Bhavcopy/Processed\AGSTRA.csv
# Saved ../Data/Bhavcopy/Processed\AHLADA.csv
# Saved ../Data/Bhavcopy/Processed\AHLEAST.csv
# Saved ../Data/Bhavcopy/Processed\AHLUCONT.csv
# Saved ../Data/Bhavcopy/Processed\AHLWEST.csv
# Saved ../Data/Bhavcopy/Processed\AIAENG.csv
# Saved ../Data/Bhavcopy/Processed\AIFL.csv
# Saved ../Data/Bhavcopy/Processed\AIONJSW.csv
# Saved ../Data/Bhavcopy/Processed\AIRAN.csv
# Saved ../Data/Bhavcopy/Processed\AIROLAM.csv
# Saved ../Data/Bhavcopy/Processed\AJANTPHARM.csv
# Saved ../Data/Bhavcopy/Processed\AJMERA.csv
# Saved ../Data/Bhavcopy/Processed\AJOONI.csv
# Saved ../Data/Bhavcopy/Processed\AJRINFRA.csv
# Saved ../Data/Bhavcopy/Processed\AKASH.csv
# Saved ../Data/Bhavcopy/Processed\AKG.csv
# Saved ../Data/Bhavcopy/Processed\AKSHARCHEM.csv
# Saved ../Data/Bhavcopy/Processed\AKSHOPTFBR.csv
# Saved ../Data/Bhavcopy/Processed\AKZOINDIA.csv
# Saved ../Data/Bhavcopy/Processed\ALANKIT.csv
# Saved ../Data/Bhavcopy/Processed\ALBERTDAVD.csv
# Saved ../Data/Bhavcopy/Processed\ALBK.csv
# Saved ../Data/Bhavcopy/Processed\ALCHEM.csv
# Saved ../Data/Bhavcopy/Processed\ALEMBICLTD.csv
# Saved ../Data/Bhavcopy/Processed\ALICON.csv
# Saved ../Data/Bhavcopy/Processed\ALKALI.csv
# Saved ../Data/Bhavcopy/Processed\ALKEM.csv
# Saved ../Data/Bhavcopy/Processed\ALKYLAMINE.csv
# Saved ../Data/Bhavcopy/Processed\ALLCARGO.csv
# Saved ../Data/Bhavcopy/Processed\ALLSEC.csv
# Saved ../Data/Bhavcopy/Processed\ALMONDZ.csv
# Saved ../Data/Bhavcopy/Processed\ALOKINDS.csv
# Saved ../Data/Bhavcopy/Processed\ALOKTEXT.csv
# Saved ../Data/Bhavcopy/Processed\ALPA.csv
# Saved ../Data/Bhavcopy/Processed\ALPHAGEO.csv
# Saved ../Data/Bhavcopy/Processed\ALPSINDUS.csv
# Saved ../Data/Bhavcopy/Processed\AMARAJABAT.csv
# Saved ../Data/Bhavcopy/Processed\AMBER.csv
# Saved ../Data/Bhavcopy/Processed\AMBICAAGAR.csv
# Saved ../Data/Bhavcopy/Processed\AMBIKCO.csv
# Saved ../Data/Bhavcopy/Processed\AMBUJACEM.csv
# Saved ../Data/Bhavcopy/Processed\AMDIND.csv
# Saved ../Data/Bhavcopy/Processed\AMIORG.csv
# Saved ../Data/Bhavcopy/Processed\AMJLAND.csv
# Saved ../Data/Bhavcopy/Processed\AMRUTANJAN.csv
# Saved ../Data/Bhavcopy/Processed\AMTEKAUTO.csv
# Saved ../Data/Bhavcopy/Processed\AMTL.csv
# Saved ../Data/Bhavcopy/Processed\ANANDRATHI.csv
# Saved ../Data/Bhavcopy/Processed\ANANTRAJ.csv
# Saved ../Data/Bhavcopy/Processed\ANDHRABANK.csv
# Saved ../Data/Bhavcopy/Processed\ANDHRACEMT.csv
# Saved ../Data/Bhavcopy/Processed\ANDHRAPAP.csv
# Saved ../Data/Bhavcopy/Processed\ANDHRSUGAR.csv
# Saved ../Data/Bhavcopy/Processed\ANDREWYU.csv
# Saved ../Data/Bhavcopy/Processed\ANGELBRKG.csv
# Saved ../Data/Bhavcopy/Processed\ANGELONE.csv
# Saved ../Data/Bhavcopy/Processed\ANGIND.csv
# Saved ../Data/Bhavcopy/Processed\ANIKINDS.csv
# Saved ../Data/Bhavcopy/Processed\ANKITMETAL.csv
# Saved ../Data/Bhavcopy/Processed\ANMOL.csv
# Saved ../Data/Bhavcopy/Processed\ANSALAPI.csv
# Saved ../Data/Bhavcopy/Processed\ANSALHSG.csv
# Saved ../Data/Bhavcopy/Processed\ANUP.csv
# Saved ../Data/Bhavcopy/Processed\ANURAS.csv
# Saved ../Data/Bhavcopy/Processed\APARINDS.csv
# Saved ../Data/Bhavcopy/Processed\APCL.csv
# Saved ../Data/Bhavcopy/Processed\APCOTEXIND.csv
# Saved ../Data/Bhavcopy/Processed\APEX.csv
# Saved ../Data/Bhavcopy/Processed\APLAPOLLO.csv
# Saved ../Data/Bhavcopy/Processed\APLLTD.csv
# Saved ../Data/Bhavcopy/Processed\APOLLO.csv
# Saved ../Data/Bhavcopy/Processed\APOLLOHOSP.csv
# Saved ../Data/Bhavcopy/Processed\APOLLOPIPE.csv
# Saved ../Data/Bhavcopy/Processed\APOLLOTYRE.csv
# Saved ../Data/Bhavcopy/Processed\APOLSINHOT.csv
# Saved ../Data/Bhavcopy/Processed\APTECHT.csv
# Saved ../Data/Bhavcopy/Processed\APTUS.csv
# Saved ../Data/Bhavcopy/Processed\ARCHIDPLY.csv
# Saved ../Data/Bhavcopy/Processed\ARCHIES.csv
# Saved ../Data/Bhavcopy/Processed\ARCOTECH.csv
# Saved ../Data/Bhavcopy/Processed\ARENTERP.csv
# Saved ../Data/Bhavcopy/Processed\ARIES.csv
# Saved ../Data/Bhavcopy/Processed\ARIHANT.csv
# Saved ../Data/Bhavcopy/Processed\ARIHANTCAP.csv
# Saved ../Data/Bhavcopy/Processed\ARIHANTSUP.csv
# Saved ../Data/Bhavcopy/Processed\ARMANFIN.csv
# Saved ../Data/Bhavcopy/Processed\AROGRANITE.csv
# Saved ../Data/Bhavcopy/Processed\ARROWGREEN.csv
# Saved ../Data/Bhavcopy/Processed\ARROWTEX.csv
# Saved ../Data/Bhavcopy/Processed\ARSHIYA.csv
# Saved ../Data/Bhavcopy/Processed\ARSSINFRA.csv
# Saved ../Data/Bhavcopy/Processed\ARTEMISMED.csv
# Saved ../Data/Bhavcopy/Processed\ARTNIRMAN.csv
# Saved ../Data/Bhavcopy/Processed\ARVEE.csv
# Saved ../Data/Bhavcopy/Processed\ARVIND.csv
# Saved ../Data/Bhavcopy/Processed\ARVINDFASN.csv
# Saved ../Data/Bhavcopy/Processed\ARVINFRA.csv
# Saved ../Data/Bhavcopy/Processed\ARVSMART.csv
# Saved ../Data/Bhavcopy/Processed\ASAHIINDIA.csv
# Saved ../Data/Bhavcopy/Processed\ASAHISONG.csv
# Saved ../Data/Bhavcopy/Processed\ASAL.csv
# Saved ../Data/Bhavcopy/Processed\ASALCBR.csv
# Saved ../Data/Bhavcopy/Processed\ASHAPURMIN.csv
# Saved ../Data/Bhavcopy/Processed\ASHIANA.csv
# Saved ../Data/Bhavcopy/Processed\ASHIMASYN.csv
# Saved ../Data/Bhavcopy/Processed\ASHOKA.csv
# Saved ../Data/Bhavcopy/Processed\ASHOKLEY.csv
# Saved ../Data/Bhavcopy/Processed\ASIANENE.csv
# Saved ../Data/Bhavcopy/Processed\ASIANHOTNR.csv
# Saved ../Data/Bhavcopy/Processed\ASIANPAINT.csv
# Saved ../Data/Bhavcopy/Processed\ASIANTILES.csv
# Saved ../Data/Bhavcopy/Processed\ASPINWALL.csv
# Saved ../Data/Bhavcopy/Processed\ASSAMCO.csv
# Saved ../Data/Bhavcopy/Processed\ASTEC.csv
# Saved ../Data/Bhavcopy/Processed\ASTERDM.csv
# Saved ../Data/Bhavcopy/Processed\ASTRAL.csv
# Saved ../Data/Bhavcopy/Processed\ASTRAMICRO.csv
# Saved ../Data/Bhavcopy/Processed\ASTRAZEN.csv
# Saved ../Data/Bhavcopy/Processed\ASTRON.csv
# Saved ../Data/Bhavcopy/Processed\ATFL.csv
# Saved ../Data/Bhavcopy/Processed\ATGL.csv
# Saved ../Data/Bhavcopy/Processed\ATLANTA.csv
# Saved ../Data/Bhavcopy/Processed\ATLASCYCLE.csv
# Saved ../Data/Bhavcopy/Processed\ATUL.csv
# Saved ../Data/Bhavcopy/Processed\ATULAUTO.csv
# Saved ../Data/Bhavcopy/Processed\AUBANK.csv
# Saved ../Data/Bhavcopy/Processed\AURIONPRO.csv
# Saved ../Data/Bhavcopy/Processed\AUROPHARMA.csv
# Saved ../Data/Bhavcopy/Processed\AURUM.csv
# Saved ../Data/Bhavcopy/Processed\AUSOMENT.csv
# Saved ../Data/Bhavcopy/Processed\AUSTRAL.csv
# Saved ../Data/Bhavcopy/Processed\AUTOAXLES.csv
# Saved ../Data/Bhavcopy/Processed\AUTOIND.csv
# Saved ../Data/Bhavcopy/Processed\AUTOLITIND.csv
# Saved ../Data/Bhavcopy/Processed\AVADHSUGAR.csv
# Saved ../Data/Bhavcopy/Processed\AVANTIFEED.csv
# Saved ../Data/Bhavcopy/Processed\AVTNPL.csv
# Saved ../Data/Bhavcopy/Processed\AWHCL.csv
# Saved ../Data/Bhavcopy/Processed\AXISBANK.csv
# Saved ../Data/Bhavcopy/Processed\AXISBNKETF.csv
# Saved ../Data/Bhavcopy/Processed\AXISBPSETF.csv
# Saved ../Data/Bhavcopy/Processed\AXISCADES.csv
# Saved ../Data/Bhavcopy/Processed\AXISCETF.csv
# Saved ../Data/Bhavcopy/Processed\AXISGOLD.csv
# Saved ../Data/Bhavcopy/Processed\AXISHCETF.csv
# Saved ../Data/Bhavcopy/Processed\AXISNIFTY.csv
# Saved ../Data/Bhavcopy/Processed\AXISTECETF.csv
# Saved ../Data/Bhavcopy/Processed\AYMSYNTEX.csv
# Saved ../Data/Bhavcopy/Processed\BAFNAPH.csv
# Saved ../Data/Bhavcopy/Processed\BAFNAPHARM.csv
# Saved ../Data/Bhavcopy/Processed\BAGFILMS.csv
# Saved ../Data/Bhavcopy/Processed\BAJAJ-AUTO.csv
# Saved ../Data/Bhavcopy/Processed\BAJAJCON.csv
# Saved ../Data/Bhavcopy/Processed\BAJAJCORP.csv
# Saved ../Data/Bhavcopy/Processed\BAJAJELEC.csv
# Saved ../Data/Bhavcopy/Processed\BAJAJFINSV.csv
# Saved ../Data/Bhavcopy/Processed\BAJAJHCARE.csv
# Saved ../Data/Bhavcopy/Processed\BAJAJHIND.csv
# Saved ../Data/Bhavcopy/Processed\BAJAJHLDNG.csv
# Saved ../Data/Bhavcopy/Processed\BAJFINANCE.csv
# Saved ../Data/Bhavcopy/Processed\BALAJITELE.csv
# Saved ../Data/Bhavcopy/Processed\BALAMINES.csv
# Saved ../Data/Bhavcopy/Processed\BALAXI.csv
# Saved ../Data/Bhavcopy/Processed\BALKRISHNA.csv
# Saved ../Data/Bhavcopy/Processed\BALKRISIND.csv
# Saved ../Data/Bhavcopy/Processed\BALLARPUR.csv
# Saved ../Data/Bhavcopy/Processed\BALMLAWRIE.csv
# Saved ../Data/Bhavcopy/Processed\BALPHARMA.csv
# Saved ../Data/Bhavcopy/Processed\BALRAMCHIN.csv
# Saved ../Data/Bhavcopy/Processed\BANARBEADS.csv
# Saved ../Data/Bhavcopy/Processed\BANARISUG.csv
# Saved ../Data/Bhavcopy/Processed\BANCOINDIA.csv
# Saved ../Data/Bhavcopy/Processed\BANDHANBNK.csv
# Saved ../Data/Bhavcopy/Processed\BANG.csv
# Saved ../Data/Bhavcopy/Processed\BANKA.csv
# Saved ../Data/Bhavcopy/Processed\BANKBARODA.csv
# Saved ../Data/Bhavcopy/Processed\BANKBEES.csv
# Saved ../Data/Bhavcopy/Processed\BANKINDIA.csv
# Saved ../Data/Bhavcopy/Processed\BANSWRAS.csv
# Saved ../Data/Bhavcopy/Processed\BARBEQUE.csv
# Saved ../Data/Bhavcopy/Processed\BARTRONICS.csv
# Saved ../Data/Bhavcopy/Processed\BASF.csv
# Saved ../Data/Bhavcopy/Processed\BASML.csv
# Saved ../Data/Bhavcopy/Processed\BATAINDIA.csv
# Saved ../Data/Bhavcopy/Processed\BAYERCROP.csv
# Saved ../Data/Bhavcopy/Processed\BBETF0432.csv
# Saved ../Data/Bhavcopy/Processed\BBL.csv
# Saved ../Data/Bhavcopy/Processed\BBOX.csv
# Saved ../Data/Bhavcopy/Processed\BBTC.csv
# Saved ../Data/Bhavcopy/Processed\BCG.csv
# Saved ../Data/Bhavcopy/Processed\BCLIND.csv
# Saved ../Data/Bhavcopy/Processed\BCP.csv
# Saved ../Data/Bhavcopy/Processed\BDL.csv
# Saved ../Data/Bhavcopy/Processed\BEARDSELL.csv
# Saved ../Data/Bhavcopy/Processed\BECTORFOOD.csv
# Saved ../Data/Bhavcopy/Processed\BEDMUTHA.csv
# Saved ../Data/Bhavcopy/Processed\BEL.csv
# Saved ../Data/Bhavcopy/Processed\BEML.csv
# Saved ../Data/Bhavcopy/Processed\BEPL.csv
# Saved ../Data/Bhavcopy/Processed\BERGEPAINT.csv
# Saved ../Data/Bhavcopy/Processed\BESTAGRO.csv
# Saved ../Data/Bhavcopy/Processed\BFINVEST.csv
# Saved ../Data/Bhavcopy/Processed\BFUTILITIE.csv
# Saved ../Data/Bhavcopy/Processed\BGRENERGY.csv
# Saved ../Data/Bhavcopy/Processed\BHAGCHEM.csv
# Saved ../Data/Bhavcopy/Processed\BHAGERIA.csv
# Saved ../Data/Bhavcopy/Processed\BHAGYANGR.csv
# Saved ../Data/Bhavcopy/Processed\BHAGYAPROP.csv
# Saved ../Data/Bhavcopy/Processed\BHAGYNAGAR.csv
# Saved ../Data/Bhavcopy/Processed\BHANDARI.csv
# Saved ../Data/Bhavcopy/Processed\BHARATFIN.csv
# Saved ../Data/Bhavcopy/Processed\BHARATFORG.csv
# Saved ../Data/Bhavcopy/Processed\BHARATGEAR.csv
# Saved ../Data/Bhavcopy/Processed\BHARATIDIL.csv
# Saved ../Data/Bhavcopy/Processed\BHARATRAS.csv
# Saved ../Data/Bhavcopy/Processed\BHARATWIRE.csv
# Saved ../Data/Bhavcopy/Processed\BHARTIARTL.csv
# Saved ../Data/Bhavcopy/Processed\BHEL.csv
# Saved ../Data/Bhavcopy/Processed\BHUSANSTL.csv
# Saved ../Data/Bhavcopy/Processed\BIGBLOC.csv
# Saved ../Data/Bhavcopy/Processed\BIL.csv
# Saved ../Data/Bhavcopy/Processed\BILENERGY.csv
# Saved ../Data/Bhavcopy/Processed\BILPOWER.csv
# Saved ../Data/Bhavcopy/Processed\BINANIIND.csv
# Saved ../Data/Bhavcopy/Processed\BINDALAGRO.csv
# Saved ../Data/Bhavcopy/Processed\BIOCON.csv
# Saved ../Data/Bhavcopy/Processed\BIOFILCHEM.csv
# Saved ../Data/Bhavcopy/Processed\BIRLACABLE.csv
# Saved ../Data/Bhavcopy/Processed\BIRLACORPN.csv
# Saved ../Data/Bhavcopy/Processed\BIRLAMONEY.csv
# Saved ../Data/Bhavcopy/Processed\BIRLATYRE.csv
# Saved ../Data/Bhavcopy/Processed\BKMINDST.csv
# Saved ../Data/Bhavcopy/Processed\BLBLIMITED.csv
# Saved ../Data/Bhavcopy/Processed\BLISSGVS.csv
# Saved ../Data/Bhavcopy/Processed\BLKASHYAP.csv
# Saved ../Data/Bhavcopy/Processed\BLS.csv
# Saved ../Data/Bhavcopy/Processed\BLUEBLENDS.csv
# Saved ../Data/Bhavcopy/Processed\BLUECOAST.csv
# Saved ../Data/Bhavcopy/Processed\BLUEDART.csv
# Saved ../Data/Bhavcopy/Processed\BLUESTARCO.csv
# Saved ../Data/Bhavcopy/Processed\BODALCHEM.csv
# Saved ../Data/Bhavcopy/Processed\BOMDYEING.csv
# Saved ../Data/Bhavcopy/Processed\BOROLTD.csv
# Saved ../Data/Bhavcopy/Processed\BORORENEW.csv
# Saved ../Data/Bhavcopy/Processed\BOROSIL.csv
# Saved ../Data/Bhavcopy/Processed\BOSCHLTD.csv
# Saved ../Data/Bhavcopy/Processed\BPCL.csv
# Saved ../Data/Bhavcopy/Processed\BPL.csv
# Saved ../Data/Bhavcopy/Processed\BRFL.csv
# Saved ../Data/Bhavcopy/Processed\BRIGADE.csv
# Saved ../Data/Bhavcopy/Processed\BRITANNIA.csv
# Saved ../Data/Bhavcopy/Processed\BRNL.csv
# Saved ../Data/Bhavcopy/Processed\BROOKS.csv
# Saved ../Data/Bhavcopy/Processed\BSE.csv
# Saved ../Data/Bhavcopy/Processed\BSELINFRA.csv
# Saved ../Data/Bhavcopy/Processed\BSHSL.csv
# Saved ../Data/Bhavcopy/Processed\BSL.csv
# Saved ../Data/Bhavcopy/Processed\BSLGOLDETF.csv
# Saved ../Data/Bhavcopy/Processed\BSLIMITED.csv
# Saved ../Data/Bhavcopy/Processed\BSLNIFTY.csv
# Saved ../Data/Bhavcopy/Processed\BSLSENETFG.csv
# Saved ../Data/Bhavcopy/Processed\BSOFT.csv
# Saved ../Data/Bhavcopy/Processed\BURGERKING.csv
# Saved ../Data/Bhavcopy/Processed\BURNPUR.csv
# Saved ../Data/Bhavcopy/Processed\BUTTERFLY.csv
# Saved ../Data/Bhavcopy/Processed\BVCL.csv
# Saved ../Data/Bhavcopy/Processed\BYKE.csv
# Saved ../Data/Bhavcopy/Processed\CADILAHC.csv
# Saved ../Data/Bhavcopy/Processed\CAIRN.csv
# Saved ../Data/Bhavcopy/Processed\CALSOFT.csv
# Saved ../Data/Bhavcopy/Processed\CAMLINFINE.csv
# Saved ../Data/Bhavcopy/Processed\CAMS.csv
# Saved ../Data/Bhavcopy/Processed\CANBK.csv
# Saved ../Data/Bhavcopy/Processed\CANDC.csv
# Saved ../Data/Bhavcopy/Processed\CANFINHOME.csv
# Saved ../Data/Bhavcopy/Processed\CANTABIL.csv
# Saved ../Data/Bhavcopy/Processed\CAPACITE.csv
# Saved ../Data/Bhavcopy/Processed\CAPF.csv
# Saved ../Data/Bhavcopy/Processed\CAPLIPOINT.csv
# Saved ../Data/Bhavcopy/Processed\CAPTRUST.csv
# Saved ../Data/Bhavcopy/Processed\CARBORUNIV.csv
# Saved ../Data/Bhavcopy/Processed\CAREERP.csv
# Saved ../Data/Bhavcopy/Processed\CARERATING.csv
# Saved ../Data/Bhavcopy/Processed\CARTRADE.csv
# Saved ../Data/Bhavcopy/Processed\CASTEXTECH.csv
# Saved ../Data/Bhavcopy/Processed\CASTROLIND.csv
# Saved ../Data/Bhavcopy/Processed\CCCL.csv
# Saved ../Data/Bhavcopy/Processed\CCHHL.csv
# Saved ../Data/Bhavcopy/Processed\CCL.csv
# Saved ../Data/Bhavcopy/Processed\CDSL.csv
# Saved ../Data/Bhavcopy/Processed\CEATLTD.csv
# Saved ../Data/Bhavcopy/Processed\CEBBCO.csv
# Saved ../Data/Bhavcopy/Processed\CELEBRITY.csv
# Saved ../Data/Bhavcopy/Processed\CELESTIAL.csv
# Saved ../Data/Bhavcopy/Processed\CENTENKA.csv
# Saved ../Data/Bhavcopy/Processed\CENTEXT.csv
# Saved ../Data/Bhavcopy/Processed\CENTRALBK.csv
# Saved ../Data/Bhavcopy/Processed\CENTRUM.csv
# Saved ../Data/Bhavcopy/Processed\CENTUM.csv
# Saved ../Data/Bhavcopy/Processed\CENTURYPLY.csv
# Saved ../Data/Bhavcopy/Processed\CENTURYTEX.csv
# Saved ../Data/Bhavcopy/Processed\CERA.csv
# Saved ../Data/Bhavcopy/Processed\CEREBRAINT.csv
# Saved ../Data/Bhavcopy/Processed\CESC.csv
# Saved ../Data/Bhavcopy/Processed\CESCVENT.csv
# Saved ../Data/Bhavcopy/Processed\CGCL.csv
# Saved ../Data/Bhavcopy/Processed\CGPOWER.csv
# Saved ../Data/Bhavcopy/Processed\CHALET.csv
# Saved ../Data/Bhavcopy/Processed\CHAMBLFERT.csv
# Saved ../Data/Bhavcopy/Processed\CHEMBOND.csv
# Saved ../Data/Bhavcopy/Processed\CHEMCON.csv
# Saved ../Data/Bhavcopy/Processed\CHEMFAB.csv
# Saved ../Data/Bhavcopy/Processed\CHEMFALKAL.csv
# Saved ../Data/Bhavcopy/Processed\CHEMPLASTS.csv
# Saved ../Data/Bhavcopy/Processed\CHENNPETRO.csv
# Saved ../Data/Bhavcopy/Processed\CHOICEIN.csv
# Saved ../Data/Bhavcopy/Processed\CHOLAFIN.csv
# Saved ../Data/Bhavcopy/Processed\CHOLAHLDNG.csv
# Saved ../Data/Bhavcopy/Processed\CHROMATIC.csv
# Saved ../Data/Bhavcopy/Processed\CIGNITITEC.csv
# Saved ../Data/Bhavcopy/Processed\CIMMCO.csv
# Saved ../Data/Bhavcopy/Processed\CINELINE.csv
# Saved ../Data/Bhavcopy/Processed\CINEVISTA.csv
# Saved ../Data/Bhavcopy/Processed\CIPLA.csv
# Saved ../Data/Bhavcopy/Processed\CLEAN.csv
# Saved ../Data/Bhavcopy/Processed\CLEDUCATE.csv
# Saved ../Data/Bhavcopy/Processed\CLNINDIA.csv
# Saved ../Data/Bhavcopy/Processed\CLSEL.csv
# Saved ../Data/Bhavcopy/Processed\CMICABLES.csv
# Saved ../Data/Bhavcopy/Processed\CMSINFO.csv
# Saved ../Data/Bhavcopy/Processed\CNOVAPETRO.csv
# Saved ../Data/Bhavcopy/Processed\COALINDIA.csv
# Saved ../Data/Bhavcopy/Processed\COASTCORP.csv
# Saved ../Data/Bhavcopy/Processed\COCHINSHIP.csv
# Saved ../Data/Bhavcopy/Processed\COFFEEDAY.csv
# Saved ../Data/Bhavcopy/Processed\COFORGE.csv
# Saved ../Data/Bhavcopy/Processed\COLPAL.csv
# Saved ../Data/Bhavcopy/Processed\COMPINFO.csv
# Saved ../Data/Bhavcopy/Processed\COMPUSOFT.csv
# Saved ../Data/Bhavcopy/Processed\CONCOR.csv
# Saved ../Data/Bhavcopy/Processed\CONFIPET.csv
# Saved ../Data/Bhavcopy/Processed\CONSOFINVT.csv
# Saved ../Data/Bhavcopy/Processed\CONTROLPR.csv
# Saved ../Data/Bhavcopy/Processed\CORALFINAC.csv
# Saved ../Data/Bhavcopy/Processed\CORDSCABLE.csv
# Saved ../Data/Bhavcopy/Processed\COROMANDEL.csv
# Saved ../Data/Bhavcopy/Processed\CORPBANK.csv
# Saved ../Data/Bhavcopy/Processed\COSMOFILMS.csv
# Saved ../Data/Bhavcopy/Processed\COUNCODOS.csv
# Saved ../Data/Bhavcopy/Processed\COX&KINGS.csv
# Saved ../Data/Bhavcopy/Processed\CPSEETF.csv
# Saved ../Data/Bhavcopy/Processed\CRAFTSMAN.csv
# Saved ../Data/Bhavcopy/Processed\CREATIVE.csv
# Saved ../Data/Bhavcopy/Processed\CREATIVEYE.csv
# Saved ../Data/Bhavcopy/Processed\CREDITACC.csv
# Saved ../Data/Bhavcopy/Processed\CREST.csv
# Saved ../Data/Bhavcopy/Processed\CRISIL.csv
# Saved ../Data/Bhavcopy/Processed\CRMFGETF.csv
# Saved ../Data/Bhavcopy/Processed\CROMPGREAV.csv
# Saved ../Data/Bhavcopy/Processed\CROMPTON.csv
# Saved ../Data/Bhavcopy/Processed\CSBBANK.csv
# Saved ../Data/Bhavcopy/Processed\CTE.csv
# Saved ../Data/Bhavcopy/Processed\CUB.csv
# Saved ../Data/Bhavcopy/Processed\CUBEXTUB.csv
# Saved ../Data/Bhavcopy/Processed\CUMMINSIND.csv
# Saved ../Data/Bhavcopy/Processed\CUPID.csv
# Saved ../Data/Bhavcopy/Processed\CYBERMEDIA.csv
# Saved ../Data/Bhavcopy/Processed\CYBERTECH.csv
# Saved ../Data/Bhavcopy/Processed\CYIENT.csv
# Saved ../Data/Bhavcopy/Processed\DAAWAT.csv
# Saved ../Data/Bhavcopy/Processed\DABUR.csv
# Saved ../Data/Bhavcopy/Processed\DALBHARAT.csv
# Saved ../Data/Bhavcopy/Processed\DALMIABHA.csv
# Saved ../Data/Bhavcopy/Processed\DALMIASUG.csv
# Saved ../Data/Bhavcopy/Processed\DAMODARIND.csv
# Saved ../Data/Bhavcopy/Processed\DANGEE.csv
# Saved ../Data/Bhavcopy/Processed\DATAMATICS.csv
# Saved ../Data/Bhavcopy/Processed\DATAPATTNS.csv
# Saved ../Data/Bhavcopy/Processed\DBCORP.csv
# Saved ../Data/Bhavcopy/Processed\DBL.csv
# Saved ../Data/Bhavcopy/Processed\DBREALTY.csv
# Saved ../Data/Bhavcopy/Processed\DBSTOCKBRO.csv
# Saved ../Data/Bhavcopy/Processed\DCAL.csv
# Saved ../Data/Bhavcopy/Processed\DCBBANK.csv
# Saved ../Data/Bhavcopy/Processed\DCM.csv
# Saved ../Data/Bhavcopy/Processed\DCMFINSERV.csv
# Saved ../Data/Bhavcopy/Processed\DCMNVL.csv
# Saved ../Data/Bhavcopy/Processed\DCMSHRIRAM.csv
# Saved ../Data/Bhavcopy/Processed\DCMSRIND.csv
# Saved ../Data/Bhavcopy/Processed\DCW.csv
# Saved ../Data/Bhavcopy/Processed\DECCANCE.csv
# Saved ../Data/Bhavcopy/Processed\DEEPAKFERT.csv
# Saved ../Data/Bhavcopy/Processed\DEEPAKNTR.csv
# Saved ../Data/Bhavcopy/Processed\DEEPENR.csv
# Saved ../Data/Bhavcopy/Processed\DEEPIND.csv
# Saved ../Data/Bhavcopy/Processed\DEEPINDS.csv
# Saved ../Data/Bhavcopy/Processed\DELPHIFX.csv
# Saved ../Data/Bhavcopy/Processed\DELTACORP.csv
# Saved ../Data/Bhavcopy/Processed\DELTAMAGNT.csv
# Saved ../Data/Bhavcopy/Processed\DEN.csv
# Saved ../Data/Bhavcopy/Processed\DENABANK.csv
# Saved ../Data/Bhavcopy/Processed\DENORA.csv
# Saved ../Data/Bhavcopy/Processed\DEVYANI.csv
# Saved ../Data/Bhavcopy/Processed\DFMFOODS.csv
# Saved ../Data/Bhavcopy/Processed\DGCONTENT.csv
# Saved ../Data/Bhavcopy/Processed\DHAMPURSUG.csv
# Saved ../Data/Bhavcopy/Processed\DHANBANK.csv
# Saved ../Data/Bhavcopy/Processed\DHANI.csv
# Saved ../Data/Bhavcopy/Processed\DHANUKA.csv
# Saved ../Data/Bhavcopy/Processed\DHARAMSI.csv
# Saved ../Data/Bhavcopy/Processed\DHARSUGAR.csv
# Saved ../Data/Bhavcopy/Processed\DHFL.csv
# Saved ../Data/Bhavcopy/Processed\DHRUV.csv
# Saved ../Data/Bhavcopy/Processed\DHUNINV.csv
# Saved ../Data/Bhavcopy/Processed\DIAMONDYD.csv
# Saved ../Data/Bhavcopy/Processed\DIAPOWER.csv
# Saved ../Data/Bhavcopy/Processed\DICIND.csv
# Saved ../Data/Bhavcopy/Processed\DIGISPICE.csv
# Saved ../Data/Bhavcopy/Processed\DIGJAMLTD.csv
# Saved ../Data/Bhavcopy/Processed\DIL.csv
# Saved ../Data/Bhavcopy/Processed\DISHMAN.csv
# Saved ../Data/Bhavcopy/Processed\DISHTV.csv
# Saved ../Data/Bhavcopy/Processed\DIVISLAB.csv
# Saved ../Data/Bhavcopy/Processed\DIXON.csv
# Saved ../Data/Bhavcopy/Processed\DLF.csv
# Saved ../Data/Bhavcopy/Processed\DLINKINDIA.csv
# Saved ../Data/Bhavcopy/Processed\DMART.csv
# Saved ../Data/Bhavcopy/Processed\DNAMEDIA.csv
# Saved ../Data/Bhavcopy/Processed\DODLA.csv
# Saved ../Data/Bhavcopy/Processed\DOLAT.csv
# Saved ../Data/Bhavcopy/Processed\DOLATALGO.csv
# Saved ../Data/Bhavcopy/Processed\DOLLAR.csv
# Saved ../Data/Bhavcopy/Processed\DOLPHINOFF.csv
# Saved ../Data/Bhavcopy/Processed\DONEAR.csv
# Saved ../Data/Bhavcopy/Processed\DPABHUSHAN.csv
# Saved ../Data/Bhavcopy/Processed\DPL.csv
# Saved ../Data/Bhavcopy/Processed\DPSCLTD.csv
# Saved ../Data/Bhavcopy/Processed\DPWIRES.csv
# Saved ../Data/Bhavcopy/Processed\DQE.csv
# Saved ../Data/Bhavcopy/Processed\DREDGECORP.csv
# Saved ../Data/Bhavcopy/Processed\DRREDDY.csv
# Saved ../Data/Bhavcopy/Processed\DSKULKARNI.csv
# Saved ../Data/Bhavcopy/Processed\DSPN50ETF.csv
# Saved ../Data/Bhavcopy/Processed\DSPNEWETF.csv
# Saved ../Data/Bhavcopy/Processed\DSPQ50ETF.csv
# Saved ../Data/Bhavcopy/Processed\DSSL.csv
# Saved ../Data/Bhavcopy/Processed\DTIL.csv
# Saved ../Data/Bhavcopy/Processed\DUCON.csv
# Saved ../Data/Bhavcopy/Processed\DVL.csv
# Saved ../Data/Bhavcopy/Processed\DWARKESH.csv
# Saved ../Data/Bhavcopy/Processed\DYNAMATECH.csv
# Saved ../Data/Bhavcopy/Processed\DYNPRO.csv
# Saved ../Data/Bhavcopy/Processed\EASEMYTRIP.csv
# Saved ../Data/Bhavcopy/Processed\EASTSILK.csv
# Saved ../Data/Bhavcopy/Processed\EASUNREYRL.csv
# Saved ../Data/Bhavcopy/Processed\EBANK.csv
# Saved ../Data/Bhavcopy/Processed\EBBETF0423.csv
# Saved ../Data/Bhavcopy/Processed\EBBETF0425.csv
# Saved ../Data/Bhavcopy/Processed\EBBETF0430.csv
# Saved ../Data/Bhavcopy/Processed\EBBETF0431.csv
# Saved ../Data/Bhavcopy/Processed\EBIXFOREX.csv
# Saved ../Data/Bhavcopy/Processed\ECEIND.csv
# Saved ../Data/Bhavcopy/Processed\ECLERX.csv
# Saved ../Data/Bhavcopy/Processed\EDELWEISS.csv
# Saved ../Data/Bhavcopy/Processed\EDL.csv
# Saved ../Data/Bhavcopy/Processed\EDUCOMP.csv
# Saved ../Data/Bhavcopy/Processed\EICHERMOT.csv
# Saved ../Data/Bhavcopy/Processed\EIDPARRY.csv
# Saved ../Data/Bhavcopy/Processed\EIFFL.csv
# Saved ../Data/Bhavcopy/Processed\EIHAHOTELS.csv
# Saved ../Data/Bhavcopy/Processed\EIHOTEL.csv
# Saved ../Data/Bhavcopy/Processed\EIMCOELECO.csv
# Saved ../Data/Bhavcopy/Processed\EKC.csv
# Saved ../Data/Bhavcopy/Processed\ELAND.csv
# Saved ../Data/Bhavcopy/Processed\ELDEHSG.csv
# Saved ../Data/Bhavcopy/Processed\ELECON.csv
# Saved ../Data/Bhavcopy/Processed\ELECTCAST.csv
# Saved ../Data/Bhavcopy/Processed\ELECTHERM.csv
# Saved ../Data/Bhavcopy/Processed\ELGIEQUIP.csv
# Saved ../Data/Bhavcopy/Processed\ELGIRUBCO.csv
# Saved ../Data/Bhavcopy/Processed\EMAMIINFRA.csv
# Saved ../Data/Bhavcopy/Processed\EMAMILTD.csv
# Saved ../Data/Bhavcopy/Processed\EMAMIPAP.csv
# Saved ../Data/Bhavcopy/Processed\EMAMIREAL.csv
# Saved ../Data/Bhavcopy/Processed\EMCO.csv
# Saved ../Data/Bhavcopy/Processed\EMKAY.csv
# Saved ../Data/Bhavcopy/Processed\EMMBI.csv
# Saved ../Data/Bhavcopy/Processed\ENDURANCE.csv
# Saved ../Data/Bhavcopy/Processed\ENERGYDEV.csv
# Saved ../Data/Bhavcopy/Processed\ENGINERSIN.csv
# Saved ../Data/Bhavcopy/Processed\ENIL.csv
# Saved ../Data/Bhavcopy/Processed\EON.csv
# Saved ../Data/Bhavcopy/Processed\EPL.csv
# Saved ../Data/Bhavcopy/Processed\EQ30.csv
# Saved ../Data/Bhavcopy/Processed\EQUITAS.csv
# Saved ../Data/Bhavcopy/Processed\EQUITASBNK.csv
# Saved ../Data/Bhavcopy/Processed\ERIS.csv
# Saved ../Data/Bhavcopy/Processed\EROSMEDIA.csv
# Saved ../Data/Bhavcopy/Processed\ESABINDIA.csv
# Saved ../Data/Bhavcopy/Processed\ESCORTS.csv
# Saved ../Data/Bhavcopy/Processed\ESL.csv
# Saved ../Data/Bhavcopy/Processed\ESSARSHPNG.csv
# Saved ../Data/Bhavcopy/Processed\ESSDEE.csv
# Saved ../Data/Bhavcopy/Processed\ESSELPACK.csv
# Saved ../Data/Bhavcopy/Processed\ESTER.csv
# Saved ../Data/Bhavcopy/Processed\EUROCERA.csv
# Saved ../Data/Bhavcopy/Processed\EUROMULTI.csv
# Saved ../Data/Bhavcopy/Processed\EUROTEXIND.csv
# Saved ../Data/Bhavcopy/Processed\EVEREADY.csv
# Saved ../Data/Bhavcopy/Processed\EVERESTIND.csv
# Saved ../Data/Bhavcopy/Processed\EVERONN.csv
# Saved ../Data/Bhavcopy/Processed\EXCEL.csv
# Saved ../Data/Bhavcopy/Processed\EXCELCROP.csv
# Saved ../Data/Bhavcopy/Processed\EXCELINDUS.csv
# Saved ../Data/Bhavcopy/Processed\EXIDEIND.csv
# Saved ../Data/Bhavcopy/Processed\EXPLEOSOL.csv
# Saved ../Data/Bhavcopy/Processed\EXXARO.csv
# Saved ../Data/Bhavcopy/Processed\FACT.csv
# Saved ../Data/Bhavcopy/Processed\FAGBEARING.csv
# Saved ../Data/Bhavcopy/Processed\FAIRCHEM.csv
# Saved ../Data/Bhavcopy/Processed\FAIRCHEMOR.csv
# Saved ../Data/Bhavcopy/Processed\FARMAXIND.csv
# Saved ../Data/Bhavcopy/Processed\FCL.csv
# Saved ../Data/Bhavcopy/Processed\FCONSUMER.csv
# Saved ../Data/Bhavcopy/Processed\FCSSOFT.csv
# Saved ../Data/Bhavcopy/Processed\FDC.csv
# Saved ../Data/Bhavcopy/Processed\FEDDERELEC.csv
# Saved ../Data/Bhavcopy/Processed\FEDDERLOYD.csv
# Saved ../Data/Bhavcopy/Processed\FEDERALBNK.csv
# Saved ../Data/Bhavcopy/Processed\FEL.csv
# Saved ../Data/Bhavcopy/Processed\FELDVR.csv
# Saved ../Data/Bhavcopy/Processed\FIBERWEB.csv
# Saved ../Data/Bhavcopy/Processed\FIEMIND.csv
# Saved ../Data/Bhavcopy/Processed\FILATEX.csv
# Saved ../Data/Bhavcopy/Processed\FINANTECH.csv
# Saved ../Data/Bhavcopy/Processed\FINCABLES.csv
# Saved ../Data/Bhavcopy/Processed\FINEORG.csv
# Saved ../Data/Bhavcopy/Processed\FINOPB.csv
# Saved ../Data/Bhavcopy/Processed\FINPIPE.csv
# Saved ../Data/Bhavcopy/Processed\FLEXITUFF.csv
# Saved ../Data/Bhavcopy/Processed\FLFL.csv
# Saved ../Data/Bhavcopy/Processed\FLUOROCHEM.csv
# Saved ../Data/Bhavcopy/Processed\FMGOETZE.csv
# Saved ../Data/Bhavcopy/Processed\FMNL.csv
# Saved ../Data/Bhavcopy/Processed\FOCUS.csv
# Saved ../Data/Bhavcopy/Processed\FOODSIN.csv
# Saved ../Data/Bhavcopy/Processed\FORCEMOT.csv
# Saved ../Data/Bhavcopy/Processed\FORTIS.csv
# Saved ../Data/Bhavcopy/Processed\FORTUNEFIN.csv
# Saved ../Data/Bhavcopy/Processed\FOSECOIND.csv
# Saved ../Data/Bhavcopy/Processed\FRETAIL.csv
# Saved ../Data/Bhavcopy/Processed\FSC.csv
# Saved ../Data/Bhavcopy/Processed\FSL.csv
# Saved ../Data/Bhavcopy/Processed\GABRIEL.csv
# Saved ../Data/Bhavcopy/Processed\GAEL.csv
# Saved ../Data/Bhavcopy/Processed\GAIL.csv
# Saved ../Data/Bhavcopy/Processed\GAL.csv
# Saved ../Data/Bhavcopy/Processed\GALAXYSURF.csv
# Saved ../Data/Bhavcopy/Processed\GALLANTT.csv
# Saved ../Data/Bhavcopy/Processed\GALLISPAT.csv
# Saved ../Data/Bhavcopy/Processed\GAMMNINFRA.csv
# Saved ../Data/Bhavcopy/Processed\GAMMONIND.csv
# Saved ../Data/Bhavcopy/Processed\GANDHITUBE.csv
# Saved ../Data/Bhavcopy/Processed\GANECOS.csv
# Saved ../Data/Bhavcopy/Processed\GANESHBE.csv
# Saved ../Data/Bhavcopy/Processed\GANESHHOUC.csv
# Saved ../Data/Bhavcopy/Processed\GANGAFORGE.csv
# Saved ../Data/Bhavcopy/Processed\GANGESSECU.csv
# Saved ../Data/Bhavcopy/Processed\GARDENSILK.csv
# Saved ../Data/Bhavcopy/Processed\GARFIBRES.csv
# Saved ../Data/Bhavcopy/Processed\GARWALLROP.csv
# Saved ../Data/Bhavcopy/Processed\GATEWAY.csv
# Saved ../Data/Bhavcopy/Processed\GATI.csv
# Saved ../Data/Bhavcopy/Processed\GAYAHWS.csv
# Saved ../Data/Bhavcopy/Processed\GAYAPROJ.csv
# Saved ../Data/Bhavcopy/Processed\GDL.csv
# Saved ../Data/Bhavcopy/Processed\GEECEE.csv
# Saved ../Data/Bhavcopy/Processed\GEEKAYWIRE.csv
# Saved ../Data/Bhavcopy/Processed\GEMINI.csv
# Saved ../Data/Bhavcopy/Processed\GENCON.csv
# Saved ../Data/Bhavcopy/Processed\GENESYS.csv
# Saved ../Data/Bhavcopy/Processed\GENUSPAPER.csv
# Saved ../Data/Bhavcopy/Processed\GENUSPOWER.csv
# Saved ../Data/Bhavcopy/Processed\GEOJITBNPP.csv
# Saved ../Data/Bhavcopy/Processed\GEOJITFSL.csv
# Saved ../Data/Bhavcopy/Processed\GEOMETRIC.csv
# Saved ../Data/Bhavcopy/Processed\GEPIL.csv
# Saved ../Data/Bhavcopy/Processed\GESHIP.csv
# Saved ../Data/Bhavcopy/Processed\GET&D.csv
# Saved ../Data/Bhavcopy/Processed\GFLLIMITED.csv
# Saved ../Data/Bhavcopy/Processed\GFSTEELS.csv
# Saved ../Data/Bhavcopy/Processed\GHCL.csv
# Saved ../Data/Bhavcopy/Processed\GICHSGFIN.csv
# Saved ../Data/Bhavcopy/Processed\GICRE.csv
# Saved ../Data/Bhavcopy/Processed\GILLANDERS.csv
# Saved ../Data/Bhavcopy/Processed\GILLETTE.csv
# Saved ../Data/Bhavcopy/Processed\GINNIFILA.csv
# Saved ../Data/Bhavcopy/Processed\GIPCL.csv
# Saved ../Data/Bhavcopy/Processed\GISOLUTION.csv
# Saved ../Data/Bhavcopy/Processed\GITANJALI.csv
# Saved ../Data/Bhavcopy/Processed\GKWLIMITED.csv
# Saved ../Data/Bhavcopy/Processed\GLAND.csv
# Saved ../Data/Bhavcopy/Processed\GLAXO.csv
# Saved ../Data/Bhavcopy/Processed\GLENMARK.csv
# Saved ../Data/Bhavcopy/Processed\GLFL.csv
# Saved ../Data/Bhavcopy/Processed\GLOBAL.csv
# Saved ../Data/Bhavcopy/Processed\GLOBALVECT.csv
# Saved ../Data/Bhavcopy/Processed\GLOBE.csv
# Saved ../Data/Bhavcopy/Processed\GLOBOFFS.csv
# Saved ../Data/Bhavcopy/Processed\GLOBUSSPR.csv
# Saved ../Data/Bhavcopy/Processed\GLS.csv
# Saved ../Data/Bhavcopy/Processed\GMBREW.csv
# Saved ../Data/Bhavcopy/Processed\GMDCLTD.csv
# Saved ../Data/Bhavcopy/Processed\GMMPFAUDLR.csv
# Saved ../Data/Bhavcopy/Processed\GMRINFRA.csv
# Saved ../Data/Bhavcopy/Processed\GMRP&UI.csv
# Saved ../Data/Bhavcopy/Processed\GNA.csv
# Saved ../Data/Bhavcopy/Processed\GNFC.csv
# Saved ../Data/Bhavcopy/Processed\GOACARBON.csv
# Saved ../Data/Bhavcopy/Processed\GOCLCORP.csv
# Saved ../Data/Bhavcopy/Processed\GOCOLORS.csv
# Saved ../Data/Bhavcopy/Processed\GODFRYPHLP.csv
# Saved ../Data/Bhavcopy/Processed\GODHA.csv
# Saved ../Data/Bhavcopy/Processed\GODREJAGRO.csv
# Saved ../Data/Bhavcopy/Processed\GODREJCP.csv
# Saved ../Data/Bhavcopy/Processed\GODREJIND.csv
# Saved ../Data/Bhavcopy/Processed\GODREJPROP.csv
# Saved ../Data/Bhavcopy/Processed\GOKEX.csv
# Saved ../Data/Bhavcopy/Processed\GOKUL.csv
# Saved ../Data/Bhavcopy/Processed\GOKULAGRO.csv
# Saved ../Data/Bhavcopy/Processed\GOLDBEES.csv
# Saved ../Data/Bhavcopy/Processed\GOLDENTOBC.csv
# Saved ../Data/Bhavcopy/Processed\GOLDIAM.csv
# Saved ../Data/Bhavcopy/Processed\GOLDINFRA.csv
# Saved ../Data/Bhavcopy/Processed\GOLDIWIN.csv
# Saved ../Data/Bhavcopy/Processed\GOLDSHARE.csv
# Saved ../Data/Bhavcopy/Processed\GOLDTECH.csv
# Saved ../Data/Bhavcopy/Processed\GOODLUCK.csv
# Saved ../Data/Bhavcopy/Processed\GOODYEAR.csv
# Saved ../Data/Bhavcopy/Processed\GPIL.csv
# Saved ../Data/Bhavcopy/Processed\GPPL.csv
# Saved ../Data/Bhavcopy/Processed\GPTINFRA.csv
# Saved ../Data/Bhavcopy/Processed\GRANULES.csv
# Saved ../Data/Bhavcopy/Processed\GRAPHITE.csv
# Saved ../Data/Bhavcopy/Processed\GRASIM.csv
# Saved ../Data/Bhavcopy/Processed\GRAUWEIL.csv
# Saved ../Data/Bhavcopy/Processed\GRAVITA.csv
# Saved ../Data/Bhavcopy/Processed\GREAVESCOT.csv
# Saved ../Data/Bhavcopy/Processed\GREENFIRE.csv
# Saved ../Data/Bhavcopy/Processed\GREENLAM.csv
# Saved ../Data/Bhavcopy/Processed\GREENPANEL.csv
# Saved ../Data/Bhavcopy/Processed\GREENPLY.csv
# Saved ../Data/Bhavcopy/Processed\GREENPOWER.csv
# Saved ../Data/Bhavcopy/Processed\GRINDWELL.csv
# Saved ../Data/Bhavcopy/Processed\GRINFRA.csv
# Saved ../Data/Bhavcopy/Processed\GROBTEA.csv
# Saved ../Data/Bhavcopy/Processed\GRPLTD.csv
# Saved ../Data/Bhavcopy/Processed\GRSE.csv
# Saved ../Data/Bhavcopy/Processed\GRUH.csv
# Saved ../Data/Bhavcopy/Processed\GRWRHITECH.csv
# Saved ../Data/Bhavcopy/Processed\GSCLCEMENT.csv
# Saved ../Data/Bhavcopy/Processed\GSFC.csv
# Saved ../Data/Bhavcopy/Processed\GSKCONS.csv
# Saved ../Data/Bhavcopy/Processed\GSPL.csv
# Saved ../Data/Bhavcopy/Processed\GSS.csv
# Saved ../Data/Bhavcopy/Processed\GTL.csv
# Saved ../Data/Bhavcopy/Processed\GTLINFRA.csv
# Saved ../Data/Bhavcopy/Processed\GTNIND.csv
# Saved ../Data/Bhavcopy/Processed\GTNTEX.csv
# Saved ../Data/Bhavcopy/Processed\GTOFFSHORE.csv
# Saved ../Data/Bhavcopy/Processed\GTPL.csv
# Saved ../Data/Bhavcopy/Processed\GUFICBIO.csv
# Saved ../Data/Bhavcopy/Processed\GUJALKALI.csv
# Saved ../Data/Bhavcopy/Processed\GUJAPOLLO.csv
# Saved ../Data/Bhavcopy/Processed\GUJFLUORO.csv
# Saved ../Data/Bhavcopy/Processed\GUJGASLTD.csv
# Saved ../Data/Bhavcopy/Processed\GUJNRECOKE.csv
# Saved ../Data/Bhavcopy/Processed\GUJNREDVR.csv
# Saved ../Data/Bhavcopy/Processed\GULFOILLUB.csv
# Saved ../Data/Bhavcopy/Processed\GULFPETRO.csv
# Saved ../Data/Bhavcopy/Processed\GULPOLY.csv
# Saved ../Data/Bhavcopy/Processed\GVKPIL.csv
# Saved ../Data/Bhavcopy/Processed\HAL.csv
# Saved ../Data/Bhavcopy/Processed\HANUNG.csv
# Saved ../Data/Bhavcopy/Processed\HAPPSTMNDS.csv
# Saved ../Data/Bhavcopy/Processed\HARITASEAT.csv
# Saved ../Data/Bhavcopy/Processed\HARRMALAYA.csv
# Saved ../Data/Bhavcopy/Processed\HATHWAY.csv
# Saved ../Data/Bhavcopy/Processed\HATSUN.csv
# Saved ../Data/Bhavcopy/Processed\HAVELLS.csv
# Saved ../Data/Bhavcopy/Processed\HBANKETF.csv
# Saved ../Data/Bhavcopy/Processed\HBLPOWER.csv
# Saved ../Data/Bhavcopy/Processed\HBSL.csv
# Saved ../Data/Bhavcopy/Processed\HBSTOCK.csv
# Saved ../Data/Bhavcopy/Processed\HCC.csv
# Saved ../Data/Bhavcopy/Processed\HCG.csv
# Saved ../Data/Bhavcopy/Processed\HCL-INSYS.csv
# Saved ../Data/Bhavcopy/Processed\HCLTECH.csv
# Saved ../Data/Bhavcopy/Processed\HDFC.csv
# Saved ../Data/Bhavcopy/Processed\HDFCAMC.csv
# Saved ../Data/Bhavcopy/Processed\HDFCBANK.csv
# Saved ../Data/Bhavcopy/Processed\HDFCLIFE.csv
# Saved ../Data/Bhavcopy/Processed\HDFCMFGETF.csv
# Saved ../Data/Bhavcopy/Processed\HDFCNIFETF.csv
# Saved ../Data/Bhavcopy/Processed\HDFCSENETF.csv
# Saved ../Data/Bhavcopy/Processed\HDIL.csv
# Saved ../Data/Bhavcopy/Processed\HEALTHY.csv
# Saved ../Data/Bhavcopy/Processed\HECPROJECT.csv
# Saved ../Data/Bhavcopy/Processed\HEG.csv
# Saved ../Data/Bhavcopy/Processed\HEIDELBERG.csv
# Saved ../Data/Bhavcopy/Processed\HEMIPROP.csv
# Saved ../Data/Bhavcopy/Processed\HERANBA.csv
# Saved ../Data/Bhavcopy/Processed\HERCULES.csv
# Saved ../Data/Bhavcopy/Processed\HERITGFOOD.csv
# Saved ../Data/Bhavcopy/Processed\HEROMOTOCO.csv
# Saved ../Data/Bhavcopy/Processed\HESTERBIO.csv
# Saved ../Data/Bhavcopy/Processed\HEXATRADEX.csv
# Saved ../Data/Bhavcopy/Processed\HEXAWARE.csv
# Saved ../Data/Bhavcopy/Processed\HFCL.csv
# Saved ../Data/Bhavcopy/Processed\HGINFRA.csv
# Saved ../Data/Bhavcopy/Processed\HGS.csv
# Saved ../Data/Bhavcopy/Processed\HIGHGROUND.csv
# Saved ../Data/Bhavcopy/Processed\HIKAL.csv
# Saved ../Data/Bhavcopy/Processed\HIL.csv
# Saved ../Data/Bhavcopy/Processed\HILTON.csv
# Saved ../Data/Bhavcopy/Processed\HIMATSEIDE.csv
# Saved ../Data/Bhavcopy/Processed\HINDALCO.csv
# Saved ../Data/Bhavcopy/Processed\HINDCOMPOS.csv
# Saved ../Data/Bhavcopy/Processed\HINDCON.csv
# Saved ../Data/Bhavcopy/Processed\HINDCOPPER.csv
# Saved ../Data/Bhavcopy/Processed\HINDDORROL.csv
# Saved ../Data/Bhavcopy/Processed\HINDMOTORS.csv
# Saved ../Data/Bhavcopy/Processed\HINDNATGLS.csv
# Saved ../Data/Bhavcopy/Processed\HINDOILEXP.csv
# Saved ../Data/Bhavcopy/Processed\HINDPETRO.csv
# Saved ../Data/Bhavcopy/Processed\HINDSYNTEX.csv
# Saved ../Data/Bhavcopy/Processed\HINDUJAFO.csv
# Saved ../Data/Bhavcopy/Processed\HINDUJAVEN.csv
# Saved ../Data/Bhavcopy/Processed\HINDUNILVR.csv
# Saved ../Data/Bhavcopy/Processed\HINDZINC.csv
# Saved ../Data/Bhavcopy/Processed\HIRECT.csv
# Saved ../Data/Bhavcopy/Processed\HISARMETAL.csv
# Saved ../Data/Bhavcopy/Processed\HITECH.csv
# Saved ../Data/Bhavcopy/Processed\HITECHCORP.csv
# Saved ../Data/Bhavcopy/Processed\HITECHGEAR.csv
# Saved ../Data/Bhavcopy/Processed\HITECHPLAS.csv
# Saved ../Data/Bhavcopy/Processed\HLEGLAS.csv
# Saved ../Data/Bhavcopy/Processed\HLVLTD.csv
# Saved ../Data/Bhavcopy/Processed\HMVL.csv
# Saved ../Data/Bhavcopy/Processed\HNDFDS.csv
# Saved ../Data/Bhavcopy/Processed\HNGSNGBEES.csv
# Saved ../Data/Bhavcopy/Processed\HOCL.csv
# Saved ../Data/Bhavcopy/Processed\HOMEFIRST.csv
# Saved ../Data/Bhavcopy/Processed\HONAUT.csv
# Saved ../Data/Bhavcopy/Processed\HONDAPOWER.csv
# Saved ../Data/Bhavcopy/Processed\HOTELEELA.csv
# Saved ../Data/Bhavcopy/Processed\HOTELRUGBY.csv
# Saved ../Data/Bhavcopy/Processed\HOVS.csv
# Saved ../Data/Bhavcopy/Processed\HPAL.csv
# Saved ../Data/Bhavcopy/Processed\HPL.csv
# Saved ../Data/Bhavcopy/Processed\HSCL.csv
# Saved ../Data/Bhavcopy/Processed\HSIL.csv
# Saved ../Data/Bhavcopy/Processed\HTMEDIA.csv
# Saved ../Data/Bhavcopy/Processed\HUBTOWN.csv
# Saved ../Data/Bhavcopy/Processed\HUDCO.csv
# Saved ../Data/Bhavcopy/Processed\HUHTAMAKI.csv
# Saved ../Data/Bhavcopy/Processed\IBMFNIFTY.csv
# Saved ../Data/Bhavcopy/Processed\IBREALEST.csv
# Saved ../Data/Bhavcopy/Processed\IBULHSGFIN.csv
# Saved ../Data/Bhavcopy/Processed\IBULISL.csv
# Saved ../Data/Bhavcopy/Processed\IBVENTURES.csv
# Saved ../Data/Bhavcopy/Processed\IBWSL.csv
# Saved ../Data/Bhavcopy/Processed\ICEMAKE.csv
# Saved ../Data/Bhavcopy/Processed\ICICI500.csv
# Saved ../Data/Bhavcopy/Processed\ICICI5GSEC.csv
# Saved ../Data/Bhavcopy/Processed\ICICIALPLV.csv
# Saved ../Data/Bhavcopy/Processed\ICICIAUTO.csv
# Saved ../Data/Bhavcopy/Processed\ICICIB22.csv
# Saved ../Data/Bhavcopy/Processed\ICICIBANK.csv
# Saved ../Data/Bhavcopy/Processed\ICICIBANKN.csv
# Saved ../Data/Bhavcopy/Processed\ICICIBANKP.csv
# Saved ../Data/Bhavcopy/Processed\ICICICONSU.csv
# Saved ../Data/Bhavcopy/Processed\ICICIFMCG.csv
# Saved ../Data/Bhavcopy/Processed\ICICIGI.csv
# Saved ../Data/Bhavcopy/Processed\ICICIGOLD.csv
# Saved ../Data/Bhavcopy/Processed\ICICILIQ.csv
# Saved ../Data/Bhavcopy/Processed\ICICILOVOL.csv
# Saved ../Data/Bhavcopy/Processed\ICICIM150.csv
# Saved ../Data/Bhavcopy/Processed\ICICIMCAP.csv
# Saved ../Data/Bhavcopy/Processed\ICICINF100.csv
# Saved ../Data/Bhavcopy/Processed\ICICINIFTY.csv
# Saved ../Data/Bhavcopy/Processed\ICICINV20.csv
# Saved ../Data/Bhavcopy/Processed\ICICINXT50.csv
# Saved ../Data/Bhavcopy/Processed\ICICIPHARM.csv
# Saved ../Data/Bhavcopy/Processed\ICICIPRULI.csv
# Saved ../Data/Bhavcopy/Processed\ICICISENSX.csv
# Saved ../Data/Bhavcopy/Processed\ICICISILVE.csv
# Saved ../Data/Bhavcopy/Processed\ICICITECH.csv
# Saved ../Data/Bhavcopy/Processed\ICIL.csv
# Saved ../Data/Bhavcopy/Processed\ICRA.csv
# Saved ../Data/Bhavcopy/Processed\ICSA.csv
# Saved ../Data/Bhavcopy/Processed\IDBI.csv
# Saved ../Data/Bhavcopy/Processed\IDBIGOLD.csv
# Saved ../Data/Bhavcopy/Processed\IDEA.csv
# Saved ../Data/Bhavcopy/Processed\IDFC.csv
# Saved ../Data/Bhavcopy/Processed\IDFCBANK.csv
# Saved ../Data/Bhavcopy/Processed\IDFCFIRSTB.csv
# Saved ../Data/Bhavcopy/Processed\IDFNIFTYET.csv
# Saved ../Data/Bhavcopy/Processed\IEX.csv
# Saved ../Data/Bhavcopy/Processed\IFBAGRO.csv
# Saved ../Data/Bhavcopy/Processed\IFBIND.csv
# Saved ../Data/Bhavcopy/Processed\IFCI.csv
# Saved ../Data/Bhavcopy/Processed\IFGLEXPOR.csv
# Saved ../Data/Bhavcopy/Processed\IFGLREFRAC.csv
# Saved ../Data/Bhavcopy/Processed\IGARASHI.csv
# Saved ../Data/Bhavcopy/Processed\IGL.csv
# Saved ../Data/Bhavcopy/Processed\IGPL.csv
# Saved ../Data/Bhavcopy/Processed\IIFL.csv
# Saved ../Data/Bhavcopy/Processed\IIFLSEC.csv
# Saved ../Data/Bhavcopy/Processed\IIFLWAM.csv
# Saved ../Data/Bhavcopy/Processed\IITL.csv
# Saved ../Data/Bhavcopy/Processed\IL&FSENGG.csv
# Saved ../Data/Bhavcopy/Processed\IL&FSTRANS.csv
# Saved ../Data/Bhavcopy/Processed\IMAGICAA.csv
# Saved ../Data/Bhavcopy/Processed\IMFA.csv
# Saved ../Data/Bhavcopy/Processed\IMPAL.csv
# Saved ../Data/Bhavcopy/Processed\IMPEXFERRO.csv
# Saved ../Data/Bhavcopy/Processed\INCREDIBLE.csv
# Saved ../Data/Bhavcopy/Processed\INDBANK.csv
# Saved ../Data/Bhavcopy/Processed\INDHOTEL.csv
# Saved ../Data/Bhavcopy/Processed\INDIACEM.csv
# Saved ../Data/Bhavcopy/Processed\INDIAGLYCO.csv
# Saved ../Data/Bhavcopy/Processed\INDIAMART.csv
# Saved ../Data/Bhavcopy/Processed\INDIANB.csv
# Saved ../Data/Bhavcopy/Processed\INDIANCARD.csv
# Saved ../Data/Bhavcopy/Processed\INDIANHUME.csv
# Saved ../Data/Bhavcopy/Processed\INDIGO.csv
# Saved ../Data/Bhavcopy/Processed\INDIGOPNTS.csv
# Saved ../Data/Bhavcopy/Processed\INDLMETER.csv
# Saved ../Data/Bhavcopy/Processed\INDNIPPON.csv
# Saved ../Data/Bhavcopy/Processed\INDOBORAX.csv
# Saved ../Data/Bhavcopy/Processed\INDOCO.csv
# Saved ../Data/Bhavcopy/Processed\INDORAMA.csv
# Saved ../Data/Bhavcopy/Processed\INDOSOLAR.csv
# Saved ../Data/Bhavcopy/Processed\INDOSTAR.csv
# Saved ../Data/Bhavcopy/Processed\INDOTECH.csv
# Saved ../Data/Bhavcopy/Processed\INDOTHAI.csv
# Saved ../Data/Bhavcopy/Processed\INDOWIND.csv
# Saved ../Data/Bhavcopy/Processed\INDRAMEDCO.csv
# Saved ../Data/Bhavcopy/Processed\INDSWFTLAB.csv
# Saved ../Data/Bhavcopy/Processed\INDSWFTLTD.csv
# Saved ../Data/Bhavcopy/Processed\INDTERRAIN.csv
# Saved ../Data/Bhavcopy/Processed\INDUSINDBK.csv
# Saved ../Data/Bhavcopy/Processed\INDUSTOWER.csv
# Saved ../Data/Bhavcopy/Processed\INEOSSTYRO.csv
# Saved ../Data/Bhavcopy/Processed\INFIBEAM.csv
# Saved ../Data/Bhavcopy/Processed\INFINITE.csv
# Saved ../Data/Bhavcopy/Processed\INFOBEAN.csv
# Saved ../Data/Bhavcopy/Processed\INFOMEDIA.csv
# Saved ../Data/Bhavcopy/Processed\INFRABEES.csv
# Saved ../Data/Bhavcopy/Processed\INFRATEL.csv
# Saved ../Data/Bhavcopy/Processed\INFY.csv
# Saved ../Data/Bhavcopy/Processed\INGERRAND.csv
# Saved ../Data/Bhavcopy/Processed\INOXLEISUR.csv
# Saved ../Data/Bhavcopy/Processed\INOXWIND.csv
# Saved ../Data/Bhavcopy/Processed\INSECTICID.csv
# Saved ../Data/Bhavcopy/Processed\INSPIRISYS.csv
# Saved ../Data/Bhavcopy/Processed\INTEGRA.csv
# Saved ../Data/Bhavcopy/Processed\INTELLECT.csv
# Saved ../Data/Bhavcopy/Processed\INTENTECH.csv
# Saved ../Data/Bhavcopy/Processed\INTLCONV.csv
# Saved ../Data/Bhavcopy/Processed\INVENTURE.csv
# Saved ../Data/Bhavcopy/Processed\IOB.csv
# Saved ../Data/Bhavcopy/Processed\IOC.csv
# Saved ../Data/Bhavcopy/Processed\IOLCP.csv
# Saved ../Data/Bhavcopy/Processed\IONEXCHANG.csv
# Saved ../Data/Bhavcopy/Processed\IPAPPM.csv
# Saved ../Data/Bhavcopy/Processed\IPCALAB.csv
# Saved ../Data/Bhavcopy/Processed\IPL.csv
# Saved ../Data/Bhavcopy/Processed\IRB.csv
# Saved ../Data/Bhavcopy/Processed\IRCON.csv
# Saved ../Data/Bhavcopy/Processed\IRCTC.csv
# Saved ../Data/Bhavcopy/Processed\IRFC.csv
# Saved ../Data/Bhavcopy/Processed\IRIS.csv
# Saved ../Data/Bhavcopy/Processed\IRISDOREME.csv
# Saved ../Data/Bhavcopy/Processed\ISEC.csv
# Saved ../Data/Bhavcopy/Processed\ISFT.csv
# Saved ../Data/Bhavcopy/Processed\ISGEC.csv
# Saved ../Data/Bhavcopy/Processed\ISMTLTD.csv
# Saved ../Data/Bhavcopy/Processed\ITC.csv
# Saved ../Data/Bhavcopy/Processed\ITDC.csv
# Saved ../Data/Bhavcopy/Processed\ITDCEM.csv
# Saved ../Data/Bhavcopy/Processed\ITI.csv
# Saved ../Data/Bhavcopy/Processed\IVC.csv
# Saved ../Data/Bhavcopy/Processed\IVP.csv
# Saved ../Data/Bhavcopy/Processed\IVRCLINFRA.csv
# Saved ../Data/Bhavcopy/Processed\IVZINGOLD.csv
# Saved ../Data/Bhavcopy/Processed\IVZINNIFTY.csv
# Saved ../Data/Bhavcopy/Processed\IWEL.csv
# Saved ../Data/Bhavcopy/Processed\IZMO.csv
# Saved ../Data/Bhavcopy/Processed\J&KBANK.csv
# Saved ../Data/Bhavcopy/Processed\JAGRAN.csv
# Saved ../Data/Bhavcopy/Processed\JAGSNPHARM.csv
# Saved ../Data/Bhavcopy/Processed\JAIBALAJI.csv
# Saved ../Data/Bhavcopy/Processed\JAICORPLTD.csv
# Saved ../Data/Bhavcopy/Processed\JAIHINDPRO.csv
# Saved ../Data/Bhavcopy/Processed\JAIPURKURT.csv
# Saved ../Data/Bhavcopy/Processed\JAMNAAUTO.csv
# Saved ../Data/Bhavcopy/Processed\JASH.csv
# Saved ../Data/Bhavcopy/Processed\JAYAGROGN.csv
# Saved ../Data/Bhavcopy/Processed\JAYBARMARU.csv
# Saved ../Data/Bhavcopy/Processed\JAYNECOIND.csv
# Saved ../Data/Bhavcopy/Processed\JAYSREETEA.csv
# Saved ../Data/Bhavcopy/Processed\JBCHEPHARM.csv
# Saved ../Data/Bhavcopy/Processed\JBFIND.csv
# Saved ../Data/Bhavcopy/Processed\JBMA.csv
# Saved ../Data/Bhavcopy/Processed\JCHAC.csv
# Saved ../Data/Bhavcopy/Processed\JENSONICOL.csv
# Saved ../Data/Bhavcopy/Processed\JETAIRWAYS.csv
# Saved ../Data/Bhavcopy/Processed\JETFREIGHT.csv
# Saved ../Data/Bhavcopy/Processed\JHS.csv
# Saved ../Data/Bhavcopy/Processed\JINDALPHOT.csv
# Saved ../Data/Bhavcopy/Processed\JINDALPOLY.csv
# Saved ../Data/Bhavcopy/Processed\JINDALSAW.csv
# Saved ../Data/Bhavcopy/Processed\JINDALSTEL.csv
# Saved ../Data/Bhavcopy/Processed\JINDCOT.csv
# Saved ../Data/Bhavcopy/Processed\JINDRILL.csv
# Saved ../Data/Bhavcopy/Processed\JINDWORLD.csv
# Saved ../Data/Bhavcopy/Processed\JISLDVREQS.csv
# Saved ../Data/Bhavcopy/Processed\JISLJALEQS.csv
# Saved ../Data/Bhavcopy/Processed\JIYAECO.csv
# Saved ../Data/Bhavcopy/Processed\JKCEMENT.csv
# Saved ../Data/Bhavcopy/Processed\JKIL.csv
# Saved ../Data/Bhavcopy/Processed\JKLAKSHMI.csv
# Saved ../Data/Bhavcopy/Processed\JKPAPER.csv
# Saved ../Data/Bhavcopy/Processed\JKTYRE.csv
# Saved ../Data/Bhavcopy/Processed\JMA.csv
# Saved ../Data/Bhavcopy/Processed\JMCPROJECT.csv
# Saved ../Data/Bhavcopy/Processed\JMFINANCIL.csv
# Saved ../Data/Bhavcopy/Processed\JMTAUTOLTD.csv
# Saved ../Data/Bhavcopy/Processed\JOCIL.csv
# Saved ../Data/Bhavcopy/Processed\JPASSOCIAT.csv
# Saved ../Data/Bhavcopy/Processed\JPINFRATEC.csv
# Saved ../Data/Bhavcopy/Processed\JPOLYINVST.csv
# Saved ../Data/Bhavcopy/Processed\JPPOWER.csv
# Saved ../Data/Bhavcopy/Processed\JSL.csv
# Saved ../Data/Bhavcopy/Processed\JSLHISAR.csv
# Saved ../Data/Bhavcopy/Processed\JSWENERGY.csv
# Saved ../Data/Bhavcopy/Processed\JSWHL.csv
# Saved ../Data/Bhavcopy/Processed\JSWISPL.csv
# Saved ../Data/Bhavcopy/Processed\JSWSTEEL.csv
# Saved ../Data/Bhavcopy/Processed\JTEKTINDIA.csv
# Saved ../Data/Bhavcopy/Processed\JTLINFRA.csv
# Saved ../Data/Bhavcopy/Processed\JUBILANT.csv
# Saved ../Data/Bhavcopy/Processed\JUBLFOOD.csv
# Saved ../Data/Bhavcopy/Processed\JUBLINDS.csv
# Saved ../Data/Bhavcopy/Processed\JUBLINGREA.csv
# Saved ../Data/Bhavcopy/Processed\JUBLPHARMA.csv
# Saved ../Data/Bhavcopy/Processed\JUMPNET.csv
# Saved ../Data/Bhavcopy/Processed\JUNIORBEES.csv
# Saved ../Data/Bhavcopy/Processed\JUSTDIAL.csv
# Saved ../Data/Bhavcopy/Processed\JVLAGRO.csv
# Saved ../Data/Bhavcopy/Processed\JYOTHYLAB.csv
# Saved ../Data/Bhavcopy/Processed\JYOTISTRUC.csv
# Saved ../Data/Bhavcopy/Processed\KABRAEXTRU.csv
# Saved ../Data/Bhavcopy/Processed\KAJARIACER.csv
# Saved ../Data/Bhavcopy/Processed\KAKATCEM.csv
# Saved ../Data/Bhavcopy/Processed\KALINDEE.csv
# Saved ../Data/Bhavcopy/Processed\KALPATPOWR.csv
# Saved ../Data/Bhavcopy/Processed\KALYANKJIL.csv
# Saved ../Data/Bhavcopy/Processed\KAMATHOTEL.csv
# Saved ../Data/Bhavcopy/Processed\KAMDHENU.csv
# Saved ../Data/Bhavcopy/Processed\KANANIIND.csv
# Saved ../Data/Bhavcopy/Processed\KANORICHEM.csv
# Saved ../Data/Bhavcopy/Processed\KANPRPLA.csv
# Saved ../Data/Bhavcopy/Processed\KANSAINER.csv
# Saved ../Data/Bhavcopy/Processed\KAPSTON.csv
# Saved ../Data/Bhavcopy/Processed\KARDA.csv
# Saved ../Data/Bhavcopy/Processed\KARMAENG.csv
# Saved ../Data/Bhavcopy/Processed\KARURVYSYA.csv
# Saved ../Data/Bhavcopy/Processed\KAUSHALYA.csv
# Saved ../Data/Bhavcopy/Processed\KAVVERITEL.csv
# Saved ../Data/Bhavcopy/Processed\KAYA.csv
# Saved ../Data/Bhavcopy/Processed\KBCGLOBAL.csv
# Saved ../Data/Bhavcopy/Processed\KCP.csv
# Saved ../Data/Bhavcopy/Processed\KCPSUGIND.csv
# Saved ../Data/Bhavcopy/Processed\KDDL.csv
# Saved ../Data/Bhavcopy/Processed\KEC.csv
# Saved ../Data/Bhavcopy/Processed\KECL.csv
# Saved ../Data/Bhavcopy/Processed\KEERTI.csv
# Saved ../Data/Bhavcopy/Processed\KEI.csv
# Saved ../Data/Bhavcopy/Processed\KELLTONTEC.csv
# Saved ../Data/Bhavcopy/Processed\KENNAMET.csv
# Saved ../Data/Bhavcopy/Processed\KESARENT.csv
# ...
# Saved ../Data/Bhavcopy/Processed\SPLIL.csv
# Saved ../Data/Bhavcopy/Processed\SPMLINFRA.csv
# Saved ../Data/Bhavcopy/Processed\SPTL.csv
# Saved ../Data/Bhavcopy/Processed\SPYL.csv
# Saved ../Data/Bhavcopy/Processed\SQSBFSI.csv
# Saved ../Data/Bhavcopy/Processed\SREEL.csv
# Saved ../Data/Bhavcopy/Processed\SREINFRA.csv
# Saved ../Data/Bhavcopy/Processed\SRF.csv
# Saved ../Data/Bhavcopy/Processed\SRHHYPOLTD.csv
# Saved ../Data/Bhavcopy/Processed\SRIPIPES.csv
# Saved ../Data/Bhavcopy/Processed\SRPL.csv
# Saved ../Data/Bhavcopy/Processed\SRSLTD.csv
# Saved ../Data/Bhavcopy/Processed\SRTRANSFIN.csv
# Saved ../Data/Bhavcopy/Processed\SSWL.csv
# Saved ../Data/Bhavcopy/Processed\STAMPEDE.csv
# Saved ../Data/Bhavcopy/Processed\STAR.csv
# Saved ../Data/Bhavcopy/Processed\STARCEMENT.csv
# Saved ../Data/Bhavcopy/Processed\STARHEALTH.csv
# Saved ../Data/Bhavcopy/Processed\STARPAPER.csv
# Saved ../Data/Bhavcopy/Processed\STCINDIA.csv
# Saved ../Data/Bhavcopy/Processed\STEELCAS.csv
# Saved ../Data/Bhavcopy/Processed\STEELCITY.csv
# Saved ../Data/Bhavcopy/Processed\STEELXIND.csv
# Saved ../Data/Bhavcopy/Processed\STEL.csv
# Saved ../Data/Bhavcopy/Processed\STERLINBIO.csv
# Saved ../Data/Bhavcopy/Processed\STERTOOLS.csv
# Saved ../Data/Bhavcopy/Processed\STINDIA.csv
# Saved ../Data/Bhavcopy/Processed\STLTECH.csv
# Saved ../Data/Bhavcopy/Processed\STOREONE.csv
# Saved ../Data/Bhavcopy/Processed\STOVEKRAFT.csv
# Saved ../Data/Bhavcopy/Processed\STRTECH.csv
# Saved ../Data/Bhavcopy/Processed\STYLAMIND.csv
# Saved ../Data/Bhavcopy/Processed\SUBEX.csv
# Saved ../Data/Bhavcopy/Processed\SUBEXLTD.csv
# Saved ../Data/Bhavcopy/Processed\SUBROS.csv
# Saved ../Data/Bhavcopy/Processed\SUDARSCHEM.csv
# Saved ../Data/Bhavcopy/Processed\SUJANATWR.csv
# Saved ../Data/Bhavcopy/Processed\SUJANAUNI.csv
# Saved ../Data/Bhavcopy/Processed\SUMEETINDS.csv
# Saved ../Data/Bhavcopy/Processed\SUMICHEM.csv
# Saved ../Data/Bhavcopy/Processed\SUMIT.csv
# Saved ../Data/Bhavcopy/Processed\SUMMITSEC.csv
# Saved ../Data/Bhavcopy/Processed\SUNCLAYLTD.csv
# Saved ../Data/Bhavcopy/Processed\SUNDARAM.csv
# Saved ../Data/Bhavcopy/Processed\SUNDARMFIN.csv
# Saved ../Data/Bhavcopy/Processed\SUNDARMHLD.csv
# Saved ../Data/Bhavcopy/Processed\SUNDRMBRAK.csv
# Saved ../Data/Bhavcopy/Processed\SUNDRMFAST.csv
# Saved ../Data/Bhavcopy/Processed\SUNFLAG.csv
# Saved ../Data/Bhavcopy/Processed\SUNILHITEC.csv
# Saved ../Data/Bhavcopy/Processed\SUNPHARMA.csv
# Saved ../Data/Bhavcopy/Processed\SUNTECK.csv
# Saved ../Data/Bhavcopy/Processed\SUNTV.csv
# Saved ../Data/Bhavcopy/Processed\SUPERHOUSE.csv
# Saved ../Data/Bhavcopy/Processed\SUPERSPIN.csv
# Saved ../Data/Bhavcopy/Processed\SUPPETRO.csv
# Saved ../Data/Bhavcopy/Processed\SUPRAJIT.csv
# Saved ../Data/Bhavcopy/Processed\SUPREMEENG.csv
# Saved ../Data/Bhavcopy/Processed\SUPREMEIND.csv
# Saved ../Data/Bhavcopy/Processed\SUPREMEINF.csv
# Saved ../Data/Bhavcopy/Processed\SUPREMETEX.csv
# Saved ../Data/Bhavcopy/Processed\SUPRIYA.csv
# Saved ../Data/Bhavcopy/Processed\SURANAIND.csv
# Saved ../Data/Bhavcopy/Processed\SURANASOL.csv
# Saved ../Data/Bhavcopy/Processed\SURANAT&P.csv
# Saved ../Data/Bhavcopy/Processed\SURYALAXMI.csv
# Saved ../Data/Bhavcopy/Processed\SURYAROSNI.csv
# Saved ../Data/Bhavcopy/Processed\SURYODAY.csv
# Saved ../Data/Bhavcopy/Processed\SUTLEJTEX.csv
# Saved ../Data/Bhavcopy/Processed\SUULD.csv
# Saved ../Data/Bhavcopy/Processed\SUVEN.csv
# Saved ../Data/Bhavcopy/Processed\SUVENPHAR.csv
# Saved ../Data/Bhavcopy/Processed\SUVIDHAA.csv
# Saved ../Data/Bhavcopy/Processed\SUZLON.csv
# Saved ../Data/Bhavcopy/Processed\SVPGLOB.csv
# Saved ../Data/Bhavcopy/Processed\SWANENERGY.csv
# Saved ../Data/Bhavcopy/Processed\SWARAJENG.csv
# Saved ../Data/Bhavcopy/Processed\SWELECTES.csv
# Saved ../Data/Bhavcopy/Processed\SWSOLAR.csv
# Saved ../Data/Bhavcopy/Processed\SYMPHONY.csv
# Saved ../Data/Bhavcopy/Processed\SYNCOM.csv
# Saved ../Data/Bhavcopy/Processed\SYNDIBANK.csv
# Saved ../Data/Bhavcopy/Processed\SYNGENE.csv
# Saved ../Data/Bhavcopy/Processed\TAINWALCHM.csv
# Saved ../Data/Bhavcopy/Processed\TAJGVK.csv
# Saved ../Data/Bhavcopy/Processed\TAKE.csv
# Saved ../Data/Bhavcopy/Processed\TALBROAUTO.csv
# Saved ../Data/Bhavcopy/Processed\TALWALKARS.csv
# Saved ../Data/Bhavcopy/Processed\TALWGYM.csv
# Saved ../Data/Bhavcopy/Processed\TANLA.csv
# Saved ../Data/Bhavcopy/Processed\TANTIACONS.csv
# Saved ../Data/Bhavcopy/Processed\TARAJEWELS.csv
# Saved ../Data/Bhavcopy/Processed\TARAPUR.csv
# Saved ../Data/Bhavcopy/Processed\TARC.csv
# Saved ../Data/Bhavcopy/Processed\TARMAT.csv
# Saved ../Data/Bhavcopy/Processed\TARSONS.csv
# Saved ../Data/Bhavcopy/Processed\TASTYBITE.csv
# Saved ../Data/Bhavcopy/Processed\TATACHEM.csv
# Saved ../Data/Bhavcopy/Processed\TATACOFFEE.csv
# Saved ../Data/Bhavcopy/Processed\TATACOMM.csv
# Saved ../Data/Bhavcopy/Processed\TATACONSUM.csv
# Saved ../Data/Bhavcopy/Processed\TATAELXSI.csv
# Saved ../Data/Bhavcopy/Processed\TATAGLOBAL.csv
# Saved ../Data/Bhavcopy/Processed\TATAINVEST.csv
# Saved ../Data/Bhavcopy/Processed\TATAMETALI.csv
# Saved ../Data/Bhavcopy/Processed\TATAMOTORS.csv
# Saved ../Data/Bhavcopy/Processed\TATAMTRDVR.csv
# Saved ../Data/Bhavcopy/Processed\TATAPOWER.csv
# Saved ../Data/Bhavcopy/Processed\TATASPONGE.csv
# Saved ../Data/Bhavcopy/Processed\TATASTEEL.csv
# Saved ../Data/Bhavcopy/Processed\TATASTLBSL.csv
# Saved ../Data/Bhavcopy/Processed\TATASTLLP.csv
# Saved ../Data/Bhavcopy/Processed\TATVA.csv
# Saved ../Data/Bhavcopy/Processed\TBZ.csv
# Saved ../Data/Bhavcopy/Processed\TCI.csv
# Saved ../Data/Bhavcopy/Processed\TCIDEVELOP.csv
# Saved ../Data/Bhavcopy/Processed\TCIEXP.csv
# Saved ../Data/Bhavcopy/Processed\TCIFINANCE.csv
# Saved ../Data/Bhavcopy/Processed\TCNSBRANDS.csv
# Saved ../Data/Bhavcopy/Processed\TCPLPACK.csv
# Saved ../Data/Bhavcopy/Processed\TCS.csv
# Saved ../Data/Bhavcopy/Processed\TDPOWERSYS.csv
# Saved ../Data/Bhavcopy/Processed\TEAMLEASE.csv
# Saved ../Data/Bhavcopy/Processed\TECH.csv
# Saved ../Data/Bhavcopy/Processed\TECHIN.csv
# Saved ../Data/Bhavcopy/Processed\TECHM.csv
# Saved ../Data/Bhavcopy/Processed\TECHNO.csv
# Saved ../Data/Bhavcopy/Processed\TECHNOE.csv
# Saved ../Data/Bhavcopy/Processed\TECHNOFAB.csv
# Saved ../Data/Bhavcopy/Processed\TEGA.csv
# Saved ../Data/Bhavcopy/Processed\TEJASNET.csv
# Saved ../Data/Bhavcopy/Processed\TEMBO.csv
# Saved ../Data/Bhavcopy/Processed\TERASOFT.csv
# Saved ../Data/Bhavcopy/Processed\TEXINFRA.csv
# Saved ../Data/Bhavcopy/Processed\TEXMOPIPES.csv
# Saved ../Data/Bhavcopy/Processed\TEXRAIL.csv
# Saved ../Data/Bhavcopy/Processed\TFCILTD.csv
# Saved ../Data/Bhavcopy/Processed\TFL.csv
# Saved ../Data/Bhavcopy/Processed\TGBHOTELS.csv
# Saved ../Data/Bhavcopy/Processed\THANGAMAYL.csv
# Saved ../Data/Bhavcopy/Processed\THEINVEST.csv
# Saved ../Data/Bhavcopy/Processed\THEMISMED.csv
# Saved ../Data/Bhavcopy/Processed\THERMAX.csv
# Saved ../Data/Bhavcopy/Processed\THIRUSUGAR.csv
# Saved ../Data/Bhavcopy/Processed\THOMASCOOK.csv
# Saved ../Data/Bhavcopy/Processed\THYROCARE.csv
# Saved ../Data/Bhavcopy/Processed\TI.csv
# Saved ../Data/Bhavcopy/Processed\TIDEWATER.csv
# Saved ../Data/Bhavcopy/Processed\TIFIN.csv
# Saved ../Data/Bhavcopy/Processed\TIIL.csv
# Saved ../Data/Bhavcopy/Processed\TIINDIA.csv
# Saved ../Data/Bhavcopy/Processed\TIJARIA.csv
# Saved ../Data/Bhavcopy/Processed\TIL.csv
# Saved ../Data/Bhavcopy/Processed\TIMESGTY.csv
# Saved ../Data/Bhavcopy/Processed\TIMETECHNO.csv
# Saved ../Data/Bhavcopy/Processed\TIMKEN.csv
# Saved ../Data/Bhavcopy/Processed\TINPLATE.csv
# Saved ../Data/Bhavcopy/Processed\TIPSINDLTD.csv
# Saved ../Data/Bhavcopy/Processed\TIRUMALCHM.csv
# Saved ../Data/Bhavcopy/Processed\TIRUPATIFL.csv
# Saved ../Data/Bhavcopy/Processed\TITAN.csv
# Saved ../Data/Bhavcopy/Processed\TMRVL.csv
# Saved ../Data/Bhavcopy/Processed\TNIDETF.csv
# Saved ../Data/Bhavcopy/Processed\TNPETRO.csv
# Saved ../Data/Bhavcopy/Processed\TNPL.csv
# Saved ../Data/Bhavcopy/Processed\TOKYOPLAST.csv
# Saved ../Data/Bhavcopy/Processed\TORNTPHARM.csv
# Saved ../Data/Bhavcopy/Processed\TORNTPOWER.csv
# Saved ../Data/Bhavcopy/Processed\TOTAL.csv
# Saved ../Data/Bhavcopy/Processed\TOUCHWOOD.csv
# Saved ../Data/Bhavcopy/Processed\TPLPLASTEH.csv
# Saved ../Data/Bhavcopy/Processed\TREEHOUSE.csv
# Saved ../Data/Bhavcopy/Processed\TREJHARA.csv
# Saved ../Data/Bhavcopy/Processed\TRENT.csv
# Saved ../Data/Bhavcopy/Processed\TRF.csv
# Saved ../Data/Bhavcopy/Processed\TRICOM.csv
# Saved ../Data/Bhavcopy/Processed\TRIDENT.csv
# Saved ../Data/Bhavcopy/Processed\TRIGYN.csv
# Saved ../Data/Bhavcopy/Processed\TRIL.csv
# Saved ../Data/Bhavcopy/Processed\TRITURBINE.csv
# Saved ../Data/Bhavcopy/Processed\TRIVENI.csv
# Saved ../Data/Bhavcopy/Processed\TTKHLTCARE.csv
# Saved ../Data/Bhavcopy/Processed\TTKPRESTIG.csv
# Saved ../Data/Bhavcopy/Processed\TTL.csv
# Saved ../Data/Bhavcopy/Processed\TTML.csv
# Saved ../Data/Bhavcopy/Processed\TUBEINVEST.csv
# Saved ../Data/Bhavcopy/Processed\TULSI.csv
# Saved ../Data/Bhavcopy/Processed\TV18BRDCST.csv
# Saved ../Data/Bhavcopy/Processed\TVSELECT.csv
# Saved ../Data/Bhavcopy/Processed\TVSMOTOR.csv
# Saved ../Data/Bhavcopy/Processed\TVSSRICHAK.csv
# Saved ../Data/Bhavcopy/Processed\TVTODAY.csv
# Saved ../Data/Bhavcopy/Processed\TVVISION.csv
# Saved ../Data/Bhavcopy/Processed\TWL.csv
# Saved ../Data/Bhavcopy/Processed\UBHOLDINGS.csv
# Saved ../Data/Bhavcopy/Processed\UBL.csv
# Saved ../Data/Bhavcopy/Processed\UCALFUEL.csv
# Saved ../Data/Bhavcopy/Processed\UCOBANK.csv
# Saved ../Data/Bhavcopy/Processed\UDAICEMENT.csv
# Saved ../Data/Bhavcopy/Processed\UFLEX.csv
# Saved ../Data/Bhavcopy/Processed\UFO.csv
# Saved ../Data/Bhavcopy/Processed\UGARSUGAR.csv
# Saved ../Data/Bhavcopy/Processed\UGROCAP.csv
# Saved ../Data/Bhavcopy/Processed\UJAAS.csv
# Saved ../Data/Bhavcopy/Processed\UJJIVAN.csv
# Saved ../Data/Bhavcopy/Processed\UJJIVANSFB.csv
# Saved ../Data/Bhavcopy/Processed\ULTRACEMCO.csv
# Saved ../Data/Bhavcopy/Processed\UMANGDAIRY.csv
# Saved ../Data/Bhavcopy/Processed\UMESLTD.csv
# Saved ../Data/Bhavcopy/Processed\UNICHEMLAB.csv
# Saved ../Data/Bhavcopy/Processed\UNIDT.csv
# Saved ../Data/Bhavcopy/Processed\UNIENTER.csv
# Saved ../Data/Bhavcopy/Processed\UNIINFO.csv
# Saved ../Data/Bhavcopy/Processed\UNIONBANK.csv
# Saved ../Data/Bhavcopy/Processed\UNIPLY.csv
# Saved ../Data/Bhavcopy/Processed\UNITECH.csv
# Saved ../Data/Bhavcopy/Processed\UNITEDBNK.csv
# Saved ../Data/Bhavcopy/Processed\UNITEDPOLY.csv
# Saved ../Data/Bhavcopy/Processed\UNITEDTEA.csv
# Saved ../Data/Bhavcopy/Processed\UNITY.csv
# Saved ../Data/Bhavcopy/Processed\UNIVASTU.csv
# Saved ../Data/Bhavcopy/Processed\UNIVCABLES.csv
# Saved ../Data/Bhavcopy/Processed\UNIVPHOTO.csv
# Saved ../Data/Bhavcopy/Processed\UPERGANGES.csv
# Saved ../Data/Bhavcopy/Processed\UPL.csv
# Saved ../Data/Bhavcopy/Processed\URJA.csv
# Saved ../Data/Bhavcopy/Processed\USHAMART.csv
# Saved ../Data/Bhavcopy/Processed\USHERAGRO.csv
# Saved ../Data/Bhavcopy/Processed\UTIAMC.csv
# Saved ../Data/Bhavcopy/Processed\UTIBANKETF.csv
# Saved ../Data/Bhavcopy/Processed\UTINEXT50.csv
# Saved ../Data/Bhavcopy/Processed\UTINIFTETF.csv
# Saved ../Data/Bhavcopy/Processed\UTISENSETF.csv
# Saved ../Data/Bhavcopy/Processed\UTISXN50.csv
# Saved ../Data/Bhavcopy/Processed\UTTAMSTL.csv
# Saved ../Data/Bhavcopy/Processed\UTTAMSUGAR.csv
# Saved ../Data/Bhavcopy/Processed\UVSL.csv
# Saved ../Data/Bhavcopy/Processed\V2RETAIL.csv
# Saved ../Data/Bhavcopy/Processed\VADILALIND.csv
# Saved ../Data/Bhavcopy/Processed\VAIBHAVGBL.csv
# Saved ../Data/Bhavcopy/Processed\VAISHALI.csv
# Saved ../Data/Bhavcopy/Processed\VAKRANGEE.csv
# Saved ../Data/Bhavcopy/Processed\VALIANTORG.csv
# Saved ../Data/Bhavcopy/Processed\VALUEIND.csv
# Saved ../Data/Bhavcopy/Processed\VARDHACRLC.csv
# Saved ../Data/Bhavcopy/Processed\VARDMNPOLY.csv
# Saved ../Data/Bhavcopy/Processed\VARROC.csv
# Saved ../Data/Bhavcopy/Processed\VASCONEQ.csv
# Saved ../Data/Bhavcopy/Processed\VASWANI.csv
# Saved ../Data/Bhavcopy/Processed\VBL.csv
# Saved ../Data/Bhavcopy/Processed\VEDL.csv
# Saved ../Data/Bhavcopy/Processed\VENKEYS.csv
# Saved ../Data/Bhavcopy/Processed\VENUSREM.csv
# Saved ../Data/Bhavcopy/Processed\VERTOZ.csv
# Saved ../Data/Bhavcopy/Processed\VESUVIUS.csv
# Saved ../Data/Bhavcopy/Processed\VETO.csv
# Saved ../Data/Bhavcopy/Processed\VGUARD.csv
# Saved ../Data/Bhavcopy/Processed\VHL.csv
# Saved ../Data/Bhavcopy/Processed\VICEROY.csv
# Saved ../Data/Bhavcopy/Processed\VIDEOIND.csv
# Saved ../Data/Bhavcopy/Processed\VIDHIDYE.csv
# Saved ../Data/Bhavcopy/Processed\VIDHIING.csv
# Saved ../Data/Bhavcopy/Processed\VIJAYA.csv
# Saved ../Data/Bhavcopy/Processed\VIJAYABANK.csv
# Saved ../Data/Bhavcopy/Processed\VIJIFIN.csv
# Saved ../Data/Bhavcopy/Processed\VIJSHAN.csv
# Saved ../Data/Bhavcopy/Processed\VIKASECO.csv
# Saved ../Data/Bhavcopy/Processed\VIKASLIFE.csv
# Saved ../Data/Bhavcopy/Processed\VIKASMCORP.csv
# Saved ../Data/Bhavcopy/Processed\VIKASPROP.csv
# Saved ../Data/Bhavcopy/Processed\VIKASWSP.csv
# Saved ../Data/Bhavcopy/Processed\VIMALOIL.csv
# Saved ../Data/Bhavcopy/Processed\VIMTALABS.csv
# Saved ../Data/Bhavcopy/Processed\VINATIORGA.csv
# Saved ../Data/Bhavcopy/Processed\VINDHYATEL.csv
# Saved ../Data/Bhavcopy/Processed\VINEETLAB.csv
# Saved ../Data/Bhavcopy/Processed\VINYLINDIA.csv
# Saved ../Data/Bhavcopy/Processed\VIPCLOTHNG.csv
# Saved ../Data/Bhavcopy/Processed\VIPIND.csv
# Saved ../Data/Bhavcopy/Processed\VIPULLTD.csv
# Saved ../Data/Bhavcopy/Processed\VISAKAIND.csv
# Saved ../Data/Bhavcopy/Processed\VISASTEEL.csv
# Saved ../Data/Bhavcopy/Processed\VISESHINFO.csv
# Saved ../Data/Bhavcopy/Processed\VISHAL.csv
# Saved ../Data/Bhavcopy/Processed\VISHNU.csv
# Saved ../Data/Bhavcopy/Processed\VISHWARAJ.csv
# Saved ../Data/Bhavcopy/Processed\VIVIDHA.csv
# Saved ../Data/Bhavcopy/Processed\VIVIMEDLAB.csv
# Saved ../Data/Bhavcopy/Processed\VLSFINANCE.csv
# Saved ../Data/Bhavcopy/Processed\VMART.csv
# Saved ../Data/Bhavcopy/Processed\VOLTAMP.csv
# Saved ../Data/Bhavcopy/Processed\VOLTAS.csv
# Saved ../Data/Bhavcopy/Processed\VRLLOG.csv
# Saved ../Data/Bhavcopy/Processed\VSSL.csv
# Saved ../Data/Bhavcopy/Processed\VSTIND.csv
# Saved ../Data/Bhavcopy/Processed\VSTTILLERS.csv
# Saved ../Data/Bhavcopy/Processed\VTL.csv
# Saved ../Data/Bhavcopy/Processed\WABAG.csv
# Saved ../Data/Bhavcopy/Processed\WABCOINDIA.csv
# Saved ../Data/Bhavcopy/Processed\WALCHANNAG.csv
# Saved ../Data/Bhavcopy/Processed\WATERBASE.csv
# Saved ../Data/Bhavcopy/Processed\WEALTH.csv
# Saved ../Data/Bhavcopy/Processed\WEBELSOLAR.csv
# Saved ../Data/Bhavcopy/Processed\WEIZFOREX.csv
# Saved ../Data/Bhavcopy/Processed\WEIZMANIND.csv
# Saved ../Data/Bhavcopy/Processed\WELCORP.csv
# Saved ../Data/Bhavcopy/Processed\WELENT.csv
# Saved ../Data/Bhavcopy/Processed\WELINV.csv
# Saved ../Data/Bhavcopy/Processed\WELSPUNIND.csv
# Saved ../Data/Bhavcopy/Processed\WENDT.csv
# Saved ../Data/Bhavcopy/Processed\WESTLIFE.csv
# Saved ../Data/Bhavcopy/Processed\WHEELS.csv
# Saved ../Data/Bhavcopy/Processed\WHIRLPOOL.csv
# Saved ../Data/Bhavcopy/Processed\WILLAMAGOR.csv
# Saved ../Data/Bhavcopy/Processed\WINDLAS.csv
# Saved ../Data/Bhavcopy/Processed\WINDMACHIN.csv
# Saved ../Data/Bhavcopy/Processed\WINPRO.csv
# Saved ../Data/Bhavcopy/Processed\WINSOME.csv
# Saved ../Data/Bhavcopy/Processed\WIPRO.csv
# Saved ../Data/Bhavcopy/Processed\WOCKPHARMA.csv
# Saved ../Data/Bhavcopy/Processed\WONDERLA.csv
# Saved ../Data/Bhavcopy/Processed\WORTH.csv
# Saved ../Data/Bhavcopy/Processed\WSI.csv
# Saved ../Data/Bhavcopy/Processed\WSTCSTPAPR.csv
# Saved ../Data/Bhavcopy/Processed\XCHANGING.csv
# Saved ../Data/Bhavcopy/Processed\XELPMOC.csv
# Saved ../Data/Bhavcopy/Processed\XLENERGY.csv
# Saved ../Data/Bhavcopy/Processed\XPROINDIA.csv
# Saved ../Data/Bhavcopy/Processed\YAARI.csv
# Saved ../Data/Bhavcopy/Processed\YESBANK.csv
# Saved ../Data/Bhavcopy/Processed\YUKEN.csv
# Saved ../Data/Bhavcopy/Processed\ZANDUREALT.csv
# Saved ../Data/Bhavcopy/Processed\ZEEL.csv
# Saved ../Data/Bhavcopy/Processed\ZEELEARN.csv
# Saved ../Data/Bhavcopy/Processed\ZEEMEDIA.csv
# Saved ../Data/Bhavcopy/Processed\ZENITHBIR.csv
# Saved ../Data/Bhavcopy/Processed\ZENITHEXPO.csv
# Saved ../Data/Bhavcopy/Processed\ZENSARTECH.csv
# Saved ../Data/Bhavcopy/Processed\ZENTEC.csv
# Saved ../Data/Bhavcopy/Processed\ZFCVINDIA.csv
# Saved ../Data/Bhavcopy/Processed\ZICOM.csv
# Saved ../Data/Bhavcopy/Processed\ZODIACLOTH.csv
# Saved ../Data/Bhavcopy/Processed\ZODJRDMKJ.csv
# Saved ../Data/Bhavcopy/Processed\ZOMATO.csv
# Saved ../Data/Bhavcopy/Processed\ZOTA.csv
# Saved ../Data/Bhavcopy/Processed\ZUARI.csv
# Saved ../Data/Bhavcopy/Processed\ZUARIGLOB.csv
# Saved ../Data/Bhavcopy/Processed\ZYDUSLIFE.csv
# Saved ../Data/Bhavcopy/Processed\ZYDUSWELL.csv
# Saved ../Data/Bhavcopy/Processed\ZYLOG.csv

# %%
# TODO multiprocessing inside Jupyter notebook
# with multiprocessing.Pool(processes=8) as pool:
#     for result in pool.imap(enrich_symbol_data, all_symbol_data):
#         symbol = result.SYMBOL.iloc[0]
#         file_path = os.path.join(processed_data_dir, f"{symbol}.csv")
#         result.to_csv(file_path, index=True)
#         print(f"Saved {file_path}")

# %%
#| hide
nbdev.nbdev_export()
